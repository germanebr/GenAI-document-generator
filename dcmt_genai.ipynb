# %% [markdown]
# # Extracting text with Azure DocAI

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import DocumentAnalysisFeature, AnalyzeResult, AnalyzeDocumentRequest
from PIL import Image
import os
import mimetypes
import fitz #install pymupdf

# %%
# Initializing Document Intelligence endpoint
endpoint = "https://azr-hjm-intell-dev.cognitiveservices.azure.com/"

with open('azure_docai_key.txt', 'r') as file:
    API_KEY = file.read()
    
credential = AzureKeyCredential(API_KEY)
document_intelligence_client = DocumentIntelligenceClient(endpoint, credential)

# %% [markdown]
# ## Getting document information
#
# https://github.com/azure-samples/document-intelligence-code-samples/blob/main/Python(v4.0)/Layout_model/sample_analyze_layout.py
#
# This sample demonstrates how to extract text, tables, figures, selection marks and document structure (e.g., sections) information from a document given through a file.
#
# Selection marks returned from begin_analyze_document(model_id="prebuilt-layout") do not return the text associated with the checkbox. We need to manually process that data

# %%
def _in_span(word, spans):
    # Make sure the word is on the specified span (bounding box)
    for span in spans:
        if word.span.offset >= span.offset and (word.span.offset + word.span.length) <= (span.offset + span.length):
            return True
    
    return False

# %%
def get_words(page, line):
    result = []

    for word in page.words:
        if _in_span(word, line.spans):
            result.append(word)
    
    return result

# %%
# Analyze the document
base_path = 'C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/'
filename = '1817854.pdf' #sample_pdf.pdf'
file_path = ''.join([base_path, filename])

with open(file_path, "rb") as file:
    poller = document_intelligence_client.begin_analyze_document("prebuilt-layout",
                                                                 analyze_request = file,
                                                                 features = [DocumentAnalysisFeature.KEY_VALUE_PAIRS],
                                                                 content_type = "application/octet-stream")

result = poller.result()
result
# Out:
# {'apiVersion': '2024-02-29-preview', 'modelId': 'prebuilt-layout', 'stringIndexType': 'textElements', 'content': 'Lithor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nAGREEMENT FOR THE NON-EXCLUSIVE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES, ENTERED BETWEEN ETHNOR DEL ISTMO, S.A. ON THE ONE HAND (HEREINAFTER REFERRED TO AS "ETHNOR") REPRESENTED IN THIS ACT BY GABRIELA LEÓN MARCANO, BEARER OF THE VENEZUELAN PASSPORT NUMBER 101340069, AND BY THE OTHER HAND, BERMUDA GENERAL AGENCY LTD., REPRESENTED IN THIS ACT BY ALLAN FITZSIMMONS, MALE, ADULT, HOLDER OF THE PERSONAL IDENTITY CARD NUMBER 216866,WHO ACT ON HIS CAPACITY OF LEGAL REPRESNETATIVE OF THE CORPORATION, DULY AUTHORIZED TO SIGN THIS AGREEMENT (HEREINAFTER REFERRED TO AS THE "DISTRIBUTOR"), JOINTLY REFERRED TO AS THE PARTIES, IN ACCORDANCE WITH THE FOLLOWING RECITALS, TERMS AND CONDITIONS.\nRECITALS\nI. ETHNOR through its representative hereby states:\na) to be a business corporation organized in accordance with the laws of Panamá and duly registered in in the Commercial Section of the Public Registry and identified under Microjacket: 58368, Reel: 430 and Image: 162;\nb) that its domicile is located at PH TOC, floors 10 and 11, Punta Colón Street, Punta Pacifica, Panama City, Republic of Panama;\nc) that within its corporate purpose is the development, sale and marketing of pharmaceutical products;\nd) that its attorney-in-fact has the authority to enter into this Agreement for and on its behalf; It is its will to enter into this Agreement with the DISTRIBUTOR in order to obtain from the DISTRIBUTOR the distribution, commercialization and sale services for its products to be carried out in the territory of Bermuda.\nII. The DISTRIBUTOR through its representative hereby states:\na) To be a business corporation organized in accordance with the laws of Bermuda and duly registered in the Mercantile Section of the Public Registry under Company registration number: 13511.\nb) That its domicile is located at 1 Mill Creek Road, Pembroke City of Hamilton Bermuda HM05.\nc) That within its corporate purpose is the sale and marketing of pharmaceutical products in the private and public market. Likewise, it has all the licenses, permits and authorizations required to execute the services object of this Agreement;\nd) That its attorney-in-fact has the authority to enter into this Agreement for and on its behalf;\ne) That it has good general knowledge of the products covered by this Agreement, the uses thereof, ETHNOR\'s requirements and market conditions for products in Bermuda.\nf) That for the purposes of this Agreement, the term "NON-EXCLUSIVE DISTRIBUTOR" means:\n(i) That the DISTRIBUTOR is not the sole distributor authorized to sell the Agreement products to clients in Bermudas.\n(ii) That ETHNOR may, at any time in its sole discretion and without prior notice to the DISTRIBUTOR, authorize additional distributors to sell the products object of this Agreement to clients in Bermudas; and,\ng) ETHNOR is entitled, at any time in its sole discretion and without prior notice to the DISTRIBUTOR, to sell or to offer for sale the products subject of this Agreement, in Bermudas through any means or channels as deemed appropriate by ETHNOR.\nNon-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\n1\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nTithnor del Istmo, S.A.\nTHEREFORE, IN VIEW OF THE ABOVE, THE PARTIES HEREBY AGREE TO ABIDE BY AND BE BOUND BY THE FOLLOWING:\nCLAUSES\n1) COMMERCIAL TERMS:\nThe Parties agree that the commercial terms and conditions will be subject to those ones that are detailed in Annex A of this instrument; ETHNOR may vary these terms and conditions by notice in writing to the distributor with at least seven (7) business days in advance to the implementation of these changes, which will form an integral part of th ...

# %%
# Check if the document has handwritten content
if result.styles and any([style.is_handwritten for style in result.styles]):
    print("The document has handwritten content.")
else:
    print("The document does not have handwritten content.")
# Out:
# The document has handwritten content.

# %% [markdown]
# Code to get the text data from a document
# https://github.com/azure-samples/document-intelligence-code-samples/blob/main/Python(v4.0)/Layout_model/sample_analyze_layout.py
#
# `# Analyze pages.`
# `    # To learn the detailed concept of "bounding polygon" in the following content, visit: https://aka.ms/bounding-region `
# `    for page in result.pages:`
# `        print(f"----Analyzing layout from page #{page.page_number}----")`
# `        print(f"Page has width: {page.width} and height: {page.height}, measured with unit: {page.unit}")`
#
# `        # Analyze lines.`
# `        if page.lines:`
# `            for line_idx, line in enumerate(page.lines):`
# `                words = get_words(page, line)`
# `                print(`
# `                    f"...Line # {line_idx} has word count {len(words)} and text '{line.content}' "`
# `                    f"within bounding polygon '{line.polygon}'"`
# `                )`
#
# `                # Analyze words.`
# `                for word in words:`
# `                    print(f"......Word '{word.content}' has a confidence of {word.confidence}")`
#
# `       # Analyze selection marks.`
# `        if page.selection_marks:`
# `            for selection_mark in page.selection_marks:`
# `                print(`
# `                    f"Selection mark is '{selection_mark.state}' within bounding polygon "`
# `                    f"'{selection_mark.polygon}' and has a confidence of {selection_mark.confidence}"`
# `                )`
# `        # Note that selection marks returned from begin_analyze_document(model_id="prebuilt-layout") do not return the text associated with the checkbox. `
# `        # For the API to return this information, build a custom model to analyze the checkbox and its text. For detailed steps, visit: https://aka.ms/train-your-custom-model`

# %%
# Get the document text by section
def get_page_text(result):
    doc_text = {}
    content = []
    current_role = str(result.paragraphs[0].role)

    for paragraph in result.paragraphs:
        if paragraph.role in [None, 'pageHeader']:
            # Add the paragraph into the current section
            content.append(paragraph.content)
        elif (paragraph.role != 'pageNumber'):
            # Store the previous section text
            doc_text[f"Section_{len(doc_text)}"] = {'role': current_role,
                                                    'content': '\n'.join(content)}
            current_role = paragraph.role
            content = [paragraph.content]

    doc_text[f"Section_{len(doc_text)}"] = {'role': current_role,
                                            'content': '\n'.join(content)}
    
    return doc_text

# %%
get_page_text(result)
# Out:
# {'Section_0': {'role': 'None',
#   'content': 'Lithor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nAGREEMENT FOR THE NON-EXCLUSIVE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES, ENTERED BETWEEN ETHNOR DEL ISTMO, S.A. ON THE ONE HAND (HEREINAFTER REFERRED TO AS "ETHNOR") REPRESENTED IN THIS ACT BY GABRIELA LEÓN MARCANO, BEARER OF THE VENEZUELAN PASSPORT NUMBER 101340069, AND BY THE OTHER HAND, BERMUDA GENERAL AGENCY LTD., REPRESENTED IN THIS ACT BY ALLAN FITZSIMMONS, MALE, ADULT, HOLDER OF THE PERSONAL IDENTITY CARD NUMBER 216866,WHO ACT ON HIS CAPACITY OF LEGAL REPRESNETATIVE OF THE CORPORATION, DULY AUTHORIZED TO SIGN THIS AGREEMENT (HEREINAFTER REFERRED TO AS THE "DISTRIBUTOR"), JOINTLY REFERRED TO AS THE PARTIES, IN ACCORDANCE WITH THE FOLLOWING RECITALS, TERMS AND CONDITIONS.'},
#  'Section_1': {'role': 'sectionHeading',
#   'content': 'RECITALS\nI. ETHNOR through its representative hereby states:\na) to be a business corporation organized in accordance with the laws of Panamá and duly registered in in the Commercial Section of the Public Registry and identified under Microjacket: 58368, Reel: 430 and Image: 162;\nb) that its domicile is located at PH TOC, floors 10 and 11, Punta Colón Street, Punta Pacifica, Panama City, Republic of Panama;\nc) that within its corporate purpose is the development, sale and marketing of pharmaceutical products;\nd) that its attorney-in-fact has the authority to enter into this Agreement for and on its behalf; It is its will to enter into this Agreement with the DISTRIBUTOR in order to obtain from the DISTRIBUTOR the distribution, commercialization and sale services for its products to be carried out in the territory of Bermuda.\nII. The DISTRIBUTOR through its representative hereby states:\na) To be a business corporation organized in accordance with the laws of Bermuda and duly registered in the Mercantile Section of the Public Registry under Company registration number: 13511.\nb) That its domicile is located at 1 Mill Creek Road, Pembroke City of Hamilton Bermuda HM05.\nc) That within its corporate purpose is the sale and marketing of pharmaceutical products in the private and public market. Likewise, it has all the licenses, permits and authorizations required to execute the services object of this Agreement;\nd) That its attorney-in-fact has the authority to enter into this Agreement for and on its behalf;\ne) That it has good general knowledge of the products covered by this Agreement, the uses thereof, ETHNOR\'s requirements and market conditions for products in Bermuda.\nf) That for the purposes of this Agreement, the term "NON-EXCLUSIVE DISTRIBUTOR" means:\n(i) That the DISTRIBUTOR is not the sole distributor authorized to sell the Agreement products to clients in Bermudas.\n(ii) That ETHNOR may, at any time in its sole discretion and without prior notice to the DISTRIBUTOR, authorize additional distributors to sell the products object of this Agreement to clients in Bermudas; and,\ng) ETHNOR is entitled, at any time in its sole discretion and without prior notice to the DISTRIBUTOR, to sell or to offer for sale the products subject of this Agreement, in Bermudas through any means or channels as deemed appropriate by ETHNOR.'},
#  'Section_2': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nTithnor del Istmo, S.A.\nTHEREFORE, IN VIEW OF THE ABOVE, THE PARTIES HEREBY AGREE TO ABIDE BY AND BE BOUND BY THE FOLLOWING:'},
#  'Section_3': {'role': 'sectionHeading', 'content': 'CLAUSES'},
#  'Section_4': {'role': 'sectionHeading',
#   'content': '1) COMMERCIAL TERMS:\nThe Parties agree that the commercial terms and conditions will be subject to those ones that are detailed in Annex A of this instrument; ETHNOR may vary these terms and conditions by notice in writing to the distributor with at least seven (7) business days in advance to the implementation of these changes, which will form an integral part of this Agreement. The signing of this Agreement in no way implies any obligation for ETHNOR to supply the product requested by the DISTRIBUTOR through purchase orders, except if such request is supported by a procurement process whereby ETHNOR has been awarded the appropriate letter of support.'},
#  'Section_5': {'role': 'sectionHeading',
#   'content': '2) SALES TO GOVERNMENT:\nThe Parties agree that in the event the DISTRIBUTOR wishes to participate in a public process, DISTRIBUTOR shall send ETHNOR the corresponding support letter request, based on parameters established on Annex F, which forms an integral part of this Agreement, in order that ETHNOR could evaluate the viability to grant such support. The support letter proposal in no way implies the obligation for the Company to grant such support and the Company reserves the right to grant the support or not following a commercial analysis concerning the viability of the business and the alignment of its commercial strategies. In the event that the Company decides to grant the aforementioned support letter, the terms and conditions will be subject to the specific provisions provided on Annex A in the terms of the previous clause.'},
#  'Section_6': {'role': 'sectionHeading',
#   'content': "3) ETHNOR'S COMMITMENTS:\na) Provide the DISTRIBUTOR will current literature on the Products, were applicable;\nb) Provide the Products in good condition, free of any lien and encumbrance. The Products will be delivered in accordance with the terms and conditions established in the corresponding Purchase Order and will have an expiration date of no less than twelve (12) months unless agreed or provided otherwise by the Parties and if less, ETHNOR shall grant a swap guarantee letter;\nc) As manufacturer of the Products, the Company guarantees at all times the quality in the material and manufacturing processes of the Products, therefore, in the event of Products being defective, subject to prior inspection effectively confirming deficiency in its fabrication, DISTRIBUTOR may at its option and within the following three (3) days:\na) Request a replacement of the Product;\nb) Request that ETHNOR issue a credit note for the value of the Product that has been proven defective.\nd) ETHNOR guarantees that the Products comply with applicable laws and regulations, as well as with the permits, authorizations, records and requirements applicable thereto in the Territory. ETHNOR will hold harmless the DISTRIBUTOR from any conflict that may arise in case of non-compliance.\ne) It is expressly agreed that the costs associated with audits, in the terms herein set forth this document, will be paid entirely by ETHNOR and audit activities will not interfere with the normal operations of the business of the DISTRIBUTOR."},
#  'Section_7': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_8': {'role': 'pageFooter',
#   'content': "ICD Contract ID: 1817854\nEithnor del Jstma, S.A.\nf) ETHNOR has no obligation to make available to the DISTRIBUTOR any newly developed product, any product made available in other parts of the world, or any product that becomes part of the medical products of ETHNOR or its affiliates, as a result of an acquisition, merger, joint venture or other similar transaction. If ETHNOR decides to introduce any new product in all or part of the Territory, it may, in its sole discretion, offer such new products to the DISTRIBUTOR. In the event that ETHNOR offers any such new products to the DISTRIBUTOR, the Parties may subject it to the terms of this Agreement or negotiate new parameters for those new Products. In the latter case, the Parties will have a period of sixty (60) calendar days to try to negotiate a mutually satisfactory agreement for the distribution of such new Products in the Territory. In any case, ETHNOR will be free to sell the new products in the Territory through any channel that ETHNOR considers appropriate and convenient.\n4) DISTRIBUTOR'S COMMITMENTS:\na) Responsible Practices. The DISTRIBUTOR shall: (i) become familiar with the literature of all Products and further information provided by ETHNOR, as may be applicable; (ii) adopt and follow the practices of safe handling, storage, transportation and disposal practices regarding the Products, including, without limitation, all practices\nrequired by current or future governmental, federal, state, provincial or municipal regulation, as may be applicable; (iii) instruct its employees, independent contractors and agents on the safety precautions and safe practices required by the Products, if any, including, without limitation, information contained in the literature of the Products; (iv) distribute and market the Products only in the Territory stated in letter e) numeral I of Recitals of this Agreement; being prohibited its direct or indirect export; and (v) keep confidential the documentation and information provided by the Company as well as the terms and conditions of this Agreement.\nb) Unless there is an express and written authorization from ETHNOR, neither the DISTRIBUTOR, nor its Affiliates, Agents, Representatives, nor person or entity in which the DISTRIBUTOR, its Affiliates, Agents and/or Representatives are interested, may, directly or indirectly, sell, send or offer to sale or deliver, Products acquired by ETHNOR, outside the territory stated in letter e), numeral I of Recitals of this Agreement, or to anyone that the DISTRIBUTOR, its affiliates, Agents or any of their Respective Representatives, knowing, or having reason to believe that (i) it will resell or will deliver the Products covered by this Agreement outside Bermuda; and/or (ii) in any way will contribute to sale or export by any other person or entity of the Products covered by this Agreement outside Bermuda (whose participation may include, without limit, the sale made by the DISTRIBUTOR to a client who, in its turn, resells or sends the Products covered by this Agreement, to another person or entity located outside the territory or to another person or entity located in Bermuda, who will resell or will send the products outside the Territory.\nc) Count on all required authorizations, licenses and permits required to contract with the private and public sector.\nd) The DISTRIBUTOR agrees to notify ETHNOR in the event that its corporate name, corporate purpose, share structure or domicile is modified in any way and/or in case any governmental authority (federal, state/provincial or municipal) applies any sanction against the DISTRIBUTOR for any reason whatsoever. Such notice should be done within the three (3) following business days at the time the event take place.\ne) Any aspect related to fines or penalties presumably attributable to ETHNOR, must be notified via email to the following address: servicioalcliente@its.jnj.com at the moment in which the DISTRIBUTOR has knowledge o ...
#  'Section_9': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\nFormat embodied as Annex C; the request must be accompanied by the documentary support described in Annex F. The approval and validation of any sanction or fine will not be carried out if it is not properly supported under these conditions. Under no circumstances the DISTRIBUTOR may deduct fines or penalties from the invoices which are near to its due date, under the penalty of cancellation of a new invoice.\nf) The DISTRIBUTOR is committed to notify any aspect related to the exchange and return, by mail to the address: servicioalcliente@its.jnj.com at the moment when the DISTRIBUTOR has knowledge thereof; the notification process must be according to the guidelines set forth in Annex B.\ng) The DISTRIBUTOR will be committed to submit, but not limited to, a monthly business report whereby it is reviewed: general statement, progress, and particular and special circumstances inherent to the sales of products. Such report shall contain at least the following information:\n1. Inventory levels at the end of month (warehouse, ETHNOR, and ideally at the level of medical units).\n2. Situation of displacement and replacement orders at medical unit level.\n3. Review of red flags, business opportunities and validation of collaboration degree in the field between account executives, Government and local representatives of the DISTRIBUTOR.\n4. Customers\' complaints.\n5. Violations (real or alleged) of patents, trademarks, copyright of ETHNOR, or any use or unauthorized disclosure of products.\n6. Issues involving contingency for the Product or for ETHNOR.\n7. Simple copy of referrals, invoices and orders for replacement.\n8. The DISTRIBUTOR is committed to inform on the first working day of each week, the inventory available for sale in its stores as well as the inventory at the end of month, by completing the form named "monthly inventories", embodied herein as Annex E. The DISTRIBUTOR is committed to maintain inventories in the terms of this Agreement.\nh) The DISTRIBUTOR is committed to carry out the distribution, which is the object of this Agreement, on its own account, on its behalf, with experienced staff and its own resources, it is not entitled to request any refund from ETHNOR to cover the representation expenses or for any another concept related to the distribution, which is the object of this Agreement. Likewise, the DISTRIBUTOR is not entitled to hold, at any time, the title as a representative or exclusive DISTRIBUTOR of ETHNOR. The DISTRIBUTOR is allowed to sub-contract third Parties to carry out the distribution, under the terms provided in this document (Clause 13. Assignment) and always being the ETHNOR\'s responsible DISTRIBUTOR.\ni) The DISTRIBUTOR undertakes to maintain sufficient inventory in order to be able to sustain and satisfy the demand level of the Products, both in the public and private sectors, based on the actual rotation of the products, with a maximum of sixty (60) calendar days.\nj) The DISTRIBUTOR undertakes to rotate the inventory under the PEPS product management principle (FIRST INPUTS-FIRST DEPARTURES). In case of not using this methodology ETHNOR will not be obliged to replace the Products.\nk) The DISTRIBUTOR is committed to monthly inform ETHNOR the monitoring of the use of the product and its location, within the territory referred to in Subparagraph e) of the Paragraph I of Chapter of Statements of this instrument.\nl) The DISTRIBUTOR undertakes to immediately remove the product indicated by ETHNOR from the market. The costs derived from said activity will be borne by ETHNOR.'},
#  'Section_10': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson'},
#  'Section_11': {'role': 'title',
#   'content': 'Eithnor del Istmo, S.A.\nm) The DISTRIBUTOR acknowledges that ETHNOR reserves the right to grant letters of support to participate in the process of public procurement, open by the Government, when the DISTRIBUTOR deems that within its strategy there is its participation in such a process with any products that are equivalent in nature or cover the same therapeutic needs of ETHNOR\'s products. Inversely, the DISTRIBUTOR may participate with products which are equivalents of the same nature or cover the same therapeutic needs of ETHNOR\'s products in the process of public procurement which the Government opens when ETHNOR does not grant the letters of support to the DISTRIBUTOR for these bidding processes.\nn) Guarantee that they have not been excluded, suspended or disabled as DISTRIBUTOR of the Public Sector Purchasing System to participate in the contracting processes with the Government, as applicable.\no) ETHNOR reserves itself the right to assign distribution agreements based on the service experience received from the authorized DISTRIBUTORs under the terms of the current Agreement, potential synergies identified by specific projects, account growth history, promoting healthy competition among the service DISTRIBUTORS.\np) The DISTRIBUTOR will be compelled to keep ETHNOR safe and free in any complaint, claim or demand filed by third parties.\nq) ETHNOR may request the accounting records of the DISTRIBUTOR, and the documentation which support the business operations related to ETHNOR and its products, and the DISTRIBUTOR is committed to provide such reports at ETHNOR\'s request, and/or the certified evidence required in this instance, since ETHNOR is subject to the Act of Foreign Corruption Practices, (FCPA) of the United States of America.\nr) The DISTRIBUTOR may not alter the Products or detach or modify in any way the labels placed by ETHNOR on the Products without the prior written consent of ETHNOR.\ns) The DISTRIBUTOR acknowledges and agrees to not initiate concerning the Products any type of action without the prior written consent of ETHNOR.\nt) In the event that a person employed or associated with the DISTRIBUTOR becomes a public official, manager or candidate of a political party, a direct or indirect member of any government agency, the DISTRIBUTOR undertakes to communicate this situation to ETHNOR within five (5) calendar days after the appointment takes effect. Now, if the DISTRIBUTOR is aware of this assumption before it takes effect, it must inform it in advance.\nu) In the event that a person employed, associated or linked to the DISTRIBUTOR is subject to a criminal process or is part of a judicial investigation, the DISTRIBUTOR is obliged to communicate this situation to ETHNOR within five (5) calendar days following the date the DISTRIBUTOR becomes aware of the fact.\nv) Purchase orders should be requested using the form named \'PURCHASE ORDER\', duly filled, as determined by the company. All purchase order from Government / institutional channel must be submitted with the valid supporting documentary.\nw) Respecting at all times the legal distribution channels established by ETHNOR for this purpose, being compelled not to take part in any act related to black market and contraband, and must notify ETHNOR as soon as it becomes aware of any forgery, alteration and/or any breach of registered brand of the intellectual property products, even when this is only a suspicious.\nx) The Distributor must appoint a physical person within the organization to receive training from ETHNOR on protection of trade marks ("Brand Protection"), using the applicable training materials provided by ETHNOR, at least annually to all persons employed by the DISTRIBUTOR; Likewise, the DISTRIBUTOR shall also provide such training or the training materials to subcontractors'},
#  'Section_12': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_13': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEithnor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nemployed in the fulfillment of the contract (to the extent that the use of such subcontractor by the intermediary is permitted according to the contract).\ny) It is strictly prohibited to the DISTRIBUTOR the recruitment of persons less than 18 years of age for the performance of any work or service related directly or indirectly, with the provision of the service. In the event that the DISTRIBUTOR fails to fully comply as established particularly in this subparagraph, this Agreement will be terminated without any liability for ETHNOR.'},
#  'Section_14': {'role': 'sectionHeading',
#   'content': "5) PAYMENTS:\na) Payment of all and each of the bills presented from ETHNOR to DISTRIBUTOR must be executed in a maximum of sixty (60) calendar days after the date of the bill for private sector sale and ninety (90) calendar days after the date of the bill for public sector sale.\nb) Payment of all bills presented by ETHNOR, as a consequence of re-order to DISTRIBUTOR's stock, must be executed in a maximum of sixty (60) calendar days after the date of the bill for private sector sale and ninety (90) calendar days after the date of the bill for public sector sale. Payments must be in dollars of the United States of America and paid to ETHNOR in Panama or in any other place as instructed by ETHNOR. The DISTRIBUTOR undertakes to assume the banking charge corresponding to each transfer, if applicable\nc) Payments will be considered duly executed when received by ETHNOR.\nd) If DISTRIBUTOR does not comply with payment of any of the products within the time frame established in this clause, that breach in payment will constitute a breach to the present Agreement and ETHNOR will have the right (without prejudice to any other right or remedy that it could have) to:\ni. Cancel or suspend any additional deliveries to DISTRIBUTOR under any order;\nii. Charge interests to DISTRIBUTOR over any pending payments after the due date at a rate of 2% per month, calculated over the pending owed (including the interest) balance, since the due date for payment until its receipt by ETHNOR;\niii. Place DISTRIBUTOR on withholding credit;\niv. Declare immediately past due and payable all owed sums by DISTRIBUTOR to ETHNOR; and,\nv. Terminate the present Agreement, without any type of responsibility for ETHNOR."},
#  'Section_15': {'role': 'sectionHeading',
#   'content': "6) WITHDRAWAL, DESTRUCTION AND/OR REMOVAL OF PRODUCTS:\nUpon ETHNOR's notice or by local authorities' order, DISTRIBUTOR will strictly comply with ETHNOR's instructions and in accordance with current local laws regarding withdrawal, destruction or removal of any Products from DISTRIBUTOR's warehouse, clients or market.\nDISTRIBUTOR will maintain enough registries that allow it to conduct the withdrawal, destruction or removal.\nReasonable costs and expenses of DISTRIBUTOR and those imposed by current local laws related to the withdrawal, destruction or removal will be covered by ETHNOR, except those costs and expenses that result from DISTRIBUTOR's breach of Contract, failing to comply with ETHNOR's instructions or current local laws ruling the theme."},
#  'Section_16': {'role': 'sectionHeading',
#   'content': '7) GOOD BUSINESS PRACTICES:\nThe Parties agree to fulfill all the obligations as established in clause 21, which includes the compromise of comply local laws and the United States Foreign Corrupt Practices Act (FCPA), which will be part of this Agreement.'},
#  'Section_17': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nFithnor del Istmo, S.A.'},
#  'Section_18': {'role': 'sectionHeading',
#   'content': '8) NO LABOR RELATIONSHIP:\nThe Parties are independent contractors and none of the provisions of this Agreement are to be construed as forming a joint venture or a relationship of an agent, representative, employer, or employee between ETHNOR and DISTRIBUTOR. Also, DISTRIBUTOR or its employees shall not consider themselves authorized to legally bind ETHNOR in any way.\nDISTRIBUTOR agrees to defend any claim, whether individual or collective, instituted by any of its employees, workers, and/or personnel, and undertakes to hold harmless and indemnify ETHNOR from such claims, with the obligation to immediately reimburse ETHNOR for any expenditure it makes in relation to such claims. Also, ETHNOR agrees to defend any claim, whether individual or collective, instituted by any of its employees, workers, and/or personnel, and undertakes to hold harmless and indemnify DISTRIBUTOR from such claims, with the obligation to immediately reimburse DISTRIBUTOR for any expenditure it makes in relation to such claims'},
#  'Section_19': {'role': 'sectionHeading',
#   'content': "9) TERM AND TERMINATION:\nThe present Agreement shall start on the day 7th April of 2022 and shall remain in effect for two (2) years; notwithstanding the foregoing, this Agreement may be terminated at any time prior to its expiration as stated later on.\nIn case either Party decides to renew the present Agreement, each Party must provide written notice to the other Party of its intention of renewal with ninety (90) calendar days' prior notice.\nNone of the Parties has any obligation, express or implicit to celebrate a new Agreement or renew the present Agreement, at its expiration or termination thereof. The Parties furthermore agree that in case of any controversy between them or in relation with the present Agreement, including its termination or expiration, none of the Parties will have the right to prevent or hinder the celebration of new Agreements related to the matter in reference in the present Agreement. Specifically, the DISTRIBUTOR will not have the right to impede ETHNOR from selling its Products in the territory through any of the channels ETHNOR consider convenient and adequate at the time Parties solve any controversy.\nConsidering that this is a non-exclusive agreement, ETHNOR may at all times celebrate other similar agreements, identical or different to this one, without any restriction."},
#  'Section_20': {'role': 'sectionHeading',
#   'content': "10) ADVANCE TERMINATION.\nThe present Agreement may be terminated in advance at any time, as follows:\na) By simple written notice from the parties with thirty (30) days prior to the termination date established in the relevant notice, in which case ETHNOR's sole obligation will be to provide Products to meet previous obligations acquired by DISTRIBUTOR in relation to contracts entered into force with health entities in the country that ETHNOR granted support letter pending at the time it receives the termination notice;\nb) Immediately by simple written notification, if ETHNOR receives evidence confirming that DISTRIBUTOR has incurred in practices that violate local laws or the FCPA;\nc) In the event that because of unforeseen circumstances or force majeure, either Party is impossible to comply with the objective of this Agreement, in this regard, the Parties agree to make a liquidation of outstanding obligations at that time, and discontinue the validity of the Agreement up to a maximum period of thirty (30) calendar days, if within such term the fortuitous event or force majeure is no longer in existence, the Agreement will be in force once again with all its effects, prior written notice made by the Parties. Once the period of thirty (30) calendar days"},
#  'Section_21': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\nabove outlined above has elapsed, the event or force majeure that was the origin of the suspension of the Agreement, has not completely and absolutely disappeared in total and absolute way, the Parties hereby agree to make the liquidation of the obligations outstanding up to that date, if it was not previously done, and this Agreement will be terminated;\nd) That the DISTRIBUTOR is related to activities of illegal distribution or out of the channels established by ETHNOR or that it takes part in acts of black market and/or contraband, falsification, alteration and/or any violation of intellectual property, with independence that its relates to PRODUCTS or not.\nFortuitous event will be understood as any contingency beyond the reasonable control of the Parties (e.g. war or hostilities, accident, fire, explosion, public unrest, breakage of equipment, government or legislative actions or labor problems) that interferes with production, supply, transportation or consumption of the Products.\nThe aforementioned does not deter that ETHNOR could terminate this contractual relation with no liabilities when exist specific causals in the territory where Products are commercialized.'},
#  'Section_22': {'role': 'sectionHeading',
#   'content': "11) RESCISSION:\nEither Party may rescind the present Agreement in case of breach of any of the obligations established herein by the other Party.\nWhen DISTRIBUTOR is in breach of contract, ETHNOR's sole obligation will be to provide products to meet the obligation -if existing- acquired by DISTRIBUTOR in relation to contracts pending at the time of termination.\nIn the event of termination, the Parties agree that any product in the hands of the DISTRIBUTOR may be: (i) repurchased by ETHNOR at its warehouse cost, which includes nationalization expenses; or (ii) sold by the DISTRIBUTOR in the local market until the stock is exhausted.\n12) LIMITATION OF LIABILITY:\nThe DISTRIBUTOR shall not be entitled to any compensation, reimbursement or compensation for damages due to any direct or indirect damages, including without limitation, loss of profit, loss of real or projected earnings on anticipated sales or expense accounts, investments, market developments or other commitments related to the commercial activity or reputation of the DISTRIBUTOR for any breach, decrease, termination or non-renewal of this Agreement.\nIn any case, the total liability of ETHNOR for any and all claims arising, derived or as a consequence of this Agreement will be limited to cover any purchases made by the DISTRIBUTOR on or before the termination of this Agreement, with ETHNOR having the option of replacement or refund of the purchase price of the Products in question.\nAs manufacturer of the Products, ETHNOR guarantees at all times the quality in the material and manufacturing processes of the Products.\nIn case of a claim for any other concept than those mentioned in this clause, the total liability of ETHNOR towards the DISTRIBUTOR shall be limited to the maximum amount of five thousand American"},
#  'Section_23': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd'},
#  'Section_24': {'role': 'pageFooter',
#   'content': 'BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nTithnor del Istmo, S.A.\nDollars (US$ 5,000.00) as compensation generic, unique, total, absolute and final derivative of this Agreement.'},
#  'Section_25': {'role': 'sectionHeading',
#   'content': "13) ASSIGNMENT:\nUnder no circumstances may DISTRIBUTOR sell or assign to any individual or legal entity, all or part of the rights and obligations contained in this Agreement, without prior consent, evidenced in writing, by conclusive means, by ETHNOR's duly designated attorney-in-fact.\nAlso, DISTRIBUTOR is strictly forbidden to use third Parties or Patients to perform the obligations stipulated in this agreement without express written authorization from ETHNOR.\nIf ETHNOR approves contracting of a third party, DISTRIBUTOR undertakes to ensure that the third party in question signs an agreement on the same terms as specified in this agreement.\nETHNOR may assign, totally or partially, the present agreement at any moment and to any person, for which notification of such assignment -once consummated- to the CLIENT, will suffice."},
#  'Section_26': {'role': 'sectionHeading',
#   'content': "14) INSPECTIONS:\nETHNOR will have the right, during working hours, to inspect and examine DISTRIBUTOR's premises to verify the quality of storage of the Products or any other circumstance or fact related to the performance of this Agreement. DISTRIBUTOR must be given written notice of such inspection at least 48 (forty-eight) hours in advance, properly identifying the personnel ETHNOR has authorized to conduct it."},
#  'Section_27': {'role': 'sectionHeading',
#   'content': '15) CONFIDENTIALITY AND SAFEKEEPING OF FILES:\nThe Parties acknowledge and agree that all files in hardcopy or electronic form, documents or working papers contained in any media, including diskettes, magnetic tapes, CD, DVD or any others, known or to be known, whether marked with "confidential" legend or not (hereinafter referred to as "FILES AND WORKING DOCUMENTS"), made available by the other Party and its employees, agents and affiliates are the sole and exclusive property of the divulging Party.\nThe Parties undertake to use only FILES AND WORKING DOCUMENTS that the other Party provides for the purposes of this Agreement, and accordingly must observe the following File Management guidelines:\na) They are not to be used by employees, agents, affiliates or associates of the receiving Party for their own benefit.\nb) They must be generated, kept and handled separately from the receiving Party\'s own files.\nc) They are not to be stored at employees or agent of the receiving Party\' households.\nd) They must be retained under the following terms:\ni. Those provided by one of the Parties for the benefit of the other or generated by one of the Parties pursuant to this Agreement must remain in the possession of the receiving Party only for the time deemed strictly necessary and useful in relation to the object of this Agreement.\nii. The Party that receives FILES AND WORKING DOCUMENTS from the other may retain them only as long as the present Agreement remains in force, but under no circumstances beyond the expiration of this Agreement.'},
#  'Section_28': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_29': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEithnor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\niii. When this Agreement is terminated or rescinded, for any reason, FILES AND WORKING DOCUMENTS must be returned immediately to the divulging Party or must be destroyed, subject to prior approval by the other Party.\niv. The Parties agree that the application of this paragraph is subject to the condition that the Parties consensually adopt a control mechanism that permits identification of the documentation subject to return or destruction and the manner in which authorization for destruction is to be granted.'},
#  'Section_30': {'role': 'sectionHeading',
#   'content': '16) IAPP POLICY:\nThe DISTRIBUTOR will be obliged to monitor that the employees that will be RENDERING THE SERVICE covered by this Agreement, be made familiar and give full compliance to ETHNOR internal policies related to the protection of the information assets, known as IAPP Policies (for its acronym in English Information Asset Protection Policy), which ETHNOR will make available to the DISTRIBUTOR within a period not exceeding (15) calendar days counted as of the date of signature of this Agreement. Once the DISTRIBUTOR receives the IAPP Policies from ETHNOR, there will be a period not exceeding thirty (30) calendar days as of the IAPP are received, in order that the DISTRIBUTOR become familiar with these policies and may begin forthwith implementation thereof. To prove this fact, the DISTRIBUTOR shall be obliged to issue a certificate whereby it is pointed out to ETHNOR that the employees involved in the execution of this Agreement understand and will comply at all times the IAPP Policies, and that all the requirements therein contained for the handling, protection and confidentiality of information are applied, both by the company and by employees. Likewise, the DISTRIBUTOR will evidence its understanding of the legal consequences arising from the violation or breach of the requirements to keep secure the information arising from the reason of this Agreement. The Distributor must report to ETHNOR within one period not exceeding five (5) business days, any incident that constitutes unlawful disclosure of confidential information or that may compromise the proprietary information of ETHNOR. In the event that the DISTRIBUTOR or any of its employees or agents have access to the ETHNOR network and/or its computer services, the DISTRIBUTOR must report to ETHNOR the fact that one of those employees ceases to work to the DISTRIBUTOR, or whether is being transferred to one of various projects which the DISTRIBUTOR is committed under this Agreement entered with ETHNOR.\n17) NOTIFICATION:\nAll notices or communications done by Parties regarding the present Agreement, shall be given personally or send by e-email (if applies) or sent prepaid by certified mail, or courier, or telefax to the following address:\nDISTRIBUTOR:\nBermuda General Agency Ltd Address: 1 Mill Creek Road, Pembroke, Bermuda HM05 E-mail: afitzsimmons@bga.bm Telephone: +441 279 5459 / +1 441 537 6570 Attention: Allan Fitzsimmons\nETHNOR:\nETHNOR DEL ISTMO, S.A. Complejo Business Park, Edificio Sur, Piso 1, Costa del Este, Panamá City, Panamá.'},
#  'Section_31': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\nE-mail: didawson@its.jnj.com Attention: Diane Dawson\nAll notices will be considered executed at the moment they are delivered to the corresponding address, through the ordinary course of transmission.\nAll notifications and communications between the Parties must be done in English.\n18) QUALITY: THE DISTRIBUTOR shall maintain a Quality System that ensures the fulfillment of the minimum necessary requirements for the storage and distribution processes established in the regulations in force corresponding to the applicable territory.\nThe Quality System must ensure that:\na) The PRODUCTS will be acquired, kept, and delivered, in accordance with the requirements of the best Practices for Storage and Distribution.\nb) PRODUCTS will be delivered to their recipients ensuring the attributes of quality and storage conditions.\nc) Any deviations to the documented procedures must be investigated and documented.\nd) Appropriate corrective and preventive actions (CAPA) will be taken in order to correct and prevent the deviations.\nThe quality system must cover:\na) The control and review of all subcontracted activities related to the acquisition, conservation, transportation and delivery of products.\nb) The staff, facilities and equipment involved in the storage and distribution process of the products.\nc) The necessary documents that evidence the proper execution of the processes (reception, storage, assortment, supply, transportation, complaints, and returns, removal of product from the market, and handling of product of controlled conditions) storage and distribution of the products.\nThe Parties are obliged to comply with the quality agreement, attached to this document as Annex named Agreement of Responsibilities of Quality (for DISTRIBUTORS) and once signed by the parties constitutes an integral part of this instrument.\n19) HEALTH CARE COMPLIANCE (HCC):\nThe DISTRIBUTOR admits and accepts that the REMUNERATION represents the fair commercial value for the service and does not force it to purchase, to use, to expire and/or to recommend any product of ETHNOR and/or of its affiliated or subsidiary companies.\nLikewise, the DISTRIBUTOR is obliged to comply with the rules of ethical character established by the Government of Bermuda, in relation to the present matter and to obtain any permission and/or authorization by part of the Government of Bermuda that is necessary for the celebration of the present instrument.'},
#  'Section_32': {'role': 'sectionHeading',
#   'content': '20) ANTICORRUPTION LAW (FCPA): Parties agree the following:\nNon-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\n1. For the purposes of this Agreement, the term "DISTRIBUTOR" shall mean the DISTRIBUTOR who has entered into this Agreement with ETHNOR, which shall be jointly referred as the Parties.\n2. To perform the object of the present Agreement and their day-to-day activities in accordance with the standards of professional ethics, and honorably in general, as applicable laws and the ethical guidelines of the pharmaceutical industry and the industry, chamber, or association to which they belong dictate.\n3. To comply with the laws and regulations applicable to the healthcare sector and those governing matters of intellectual property, copyright, and economic competition, among others, and to refrain from violating laws that prohibit and sanction acts of corruption.\n4. Both parties acknowledge that they are familiar with the Foreign Corrupt Practices Act of the United States (the "FCPA"), its prohibitions and purposes, and will not carry out actions that may violate the FCPA or the local legislation in the present or future matter.\nBoth Parties must comply with their activities in accordance with the highest standards of ethics and with the best industry practices, including without limitation any voluntary code of practice or ethics applicable to their industry.\nIn addition to the foregoing, both Parties must comply with all laws and regulations concerning their industries and corporate purpose in the territory where they provide their services, in accordance with the provisions of this Agreement.\nNotwithstanding anything to the contrary in the Agreement, DISTRIBUTOR hereby agrees that:\ni. DISTRIBUTOR shall not perform any actions that are prohibited by local and other anti-corruption laws (collectively "Anti-Corruption Laws") that may be applicable to one or both Parties to this Agreement;\nii. DISTRIBUTOR shall not, directly or indirectly, make any payment, or offer or transfer anything of value, or agree or promise to make any payment or offer or transfer anything of value, to a government official or government employee, to any political party or any candidate for political office or to any other third party related to the transaction with the purpose of influencing decisions related to ETHNOR and/or its business in a manner that would violate Anti-Corruption Laws;\niii. DISTRIBUTOR shall not retain any government official or government employee in the performance of the Agreement unless it has been approved by ETHNOR and, if necessary, by the competent authority or authorities and such government official\'s or employee\'s employer. Furthermore, DISTRIBUTOR shall immediately advise ETHNOR in writing in the event DISTRIBUTOR becomes aware that any person engaged in the performance of the Agreement becomes a government official or employee, a political party official or a candidate for political office.\niv. DISTRIBUTOR shall designate an individual within its organization to receive training from ETHNOR on Anti-Corruption Laws as well as applicable rules on interactions with health care professionals, as mutually agreed to by the Parties. Such designated individual shall then provide such training on Anti-Corruption Laws, using applicable training materials to be provided by ETHNOR, on at least an annual basis to all persons employed by DISTRIBUTOR who perform work for ETHNOR and interact with government officials or health care professionals in the normal course of their responsibilities. Upon ETHNOR\'s and DISTRIBUTOR\'s mutual Agreement, such training may also be provided directly by ETHNOR to such employees of DISTRIBUTOR. DISTRIBUTOR shall also'},
#  'Section_33': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_34': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\nprovide such training or training materials to any subcontractors it uses in the performance of the Agreement (to the extent the use of such subcontractors by Intermediary is permitted under the Agreement.) Any training and materials provided by ETHNOR does not relieve DISTRIBUTOR of any obligations it has independent of the Agreement and DISTRIBUTOR shall not rely on ETHNOR\'s training and materials for any such obligations;\nv. DISTRIBUTOR shall certify on an annual basis in a format to be provided by ETHNOR that:\ni. Training and training materials on Anti-Corruption Laws, as well as applicable rules on interactions with health care professionals, have been provided to all persons employed by DISTRIBUTOR who perform work for ETHNOR and interact with government officials or health care professionals in the normal course of their responsibilities and that it has provided the ETHNOR training and training materials to subcontractors used by DISTRIBUTOR in the performance of the Agreement;\nii. To the best of DISTRIBUTOR\'s knowledge, there have been no violations of Anti- Corruption Laws by DISTRIBUTOR or persons employed by or subcontractors used by DISTRIBUTOR in the performance of the Agreement;\niii. Personnel of DISTRIBUTOR who may be designated as "Key Personnel" by mutual agreement of ETHNOR and DISTRIBUTOR have not changed, except as noted in a schedule attached to the certification provided by DISTRIBUTOR;\niv. DISTRIBUTOR has made no changes in its use of subcontractors to perform the services for the ETHNOR under the Agreement, except as (1) permitted under the Agreement and (2) noted in a schedule attached to the certification provided by DISTRIBUTOR; and\nV. DISTRIBUTOR has maintained true and accurate records necessary to demonstrate compliance with the requirements of this clause.\nvi. DISTRIBUTOR shall maintain and provide ETHNOR and its auditors and other representatives with access to records (financial and otherwise) and supporting documentation related to the subject matter of the Agreement as may be requested by ETHNOR in order to document or verify compliance with the provisions of this clause; and,\nvii. If DISTRIBUTOR fails to comply with any of the provisions of this section, such failure shall be deemed to be a material breach of the Agreement and, upon any such failure, ETHNOR shall have the right to terminate the Agreement with immediate effect upon written notice to DISTRIBUTOR without ETHNOR having any financial liability or other liability of any nature whatsoever resulting from any such termination.\nWithout being contrary to what is stipulated in this Agreement and its annexes, ETHNOR may disclose the terms and conditions thereof (including financial terms) when there is a request from a national and/or foreign authority, as well as third parties that in good faith (entities of the same corporate group), determine that have a legitimate need to have access to said information.'},
#  'Section_35': {'role': 'sectionHeading',
#   'content': '21) BRAND PROTECTION:\nUnder no title, the DISTRIBUTOR is not allowed to sell or assign, totally or partially, to any person whether physical or moral, local or foreign, such rights and obligations which are covered by this Agreement, without the prior written consent from ETHNOR. However, ETHNOR may assign, total or partially, this Agreement at any time and to any person, and the simply notification of the assignment to the DISTRIBUTOR will be sufficient - once such assignment is consummated.'},
#  'Section_36': {'role': 'pageFooter',
# ...
#  'Section_52': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nEithnor del Istmo, S.A.'},
#  'Section_53': {'role': 'title', 'content': 'ANNEX B RETURNS'},
#  'Section_54': {'role': 'title',
#   'content': 'OF THE AGREEMENT FOR THE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES ENTERED BETWEEN ETHNOR AND THE DISTRIBUTOR\nNotwithstanding the provisions of this Agreement and its Annexes, both Parties agree that the returns will be handled in accordance with the Return Policy signed between the Parties.\nIn addition to the terms stipulated in said Policy, the Parties agree:\nRETURNS:\nIn the case of sales to the Government, applicable product returns shall be those in respect of\na) Problems of quality.\nb) Bad condition (at the time of delivery).\nc) Missing products from point of origin.\nd) Unsolicited material.\ne) Product with expiration date less than the expiration requested in the purchase order.\nIt will be analyzed the requests of return of materials for which the DISTRIBUTOR is no longer in charge of the corresponding displacement in a Government Institute, and there is an inventory in the DISTRIBUTOR warehouse.\nThe DISTRIBUTOR will assume the responsibility for those returns that result as consequence of an omission or incorrect information instructed in the purchase order (consignee, product code, etc.).\nIn the case of sales to the private (retail) channel subject to the no return policy, applicable returns will only be those of product accepted with less than a 12-month shelf life. In such cases return will be credited at 100%.\nUnder no circumstances the DISTRIBUTOR will request returns of merchandise, for not displaced product and whose shelf life will be complete within the DISTRIBUTOR facilities, the above shall be notified in a timely manner to ETHNOR in each of the monthly business reviews. Once an Exchange or return is authorized, DISTRIBUTOR must follow-up it in conjunction with the area of CLS (Customer Logistic Service) to the corresponding logistics process.\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex B and knowing that it is an integral part of the Agreement, we subscribe to it:'},
#  'Section_55': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nEithnor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nFor DISTRIBUTOR:\nFor ETHNOR DEL ISTMO S.A.\nSignature: A. fm\nGabriela Leon Marcano\nSignature: Gabriela Leon Marcano (Oct 10, 2022 09:18 CDT) Email: gleonmar@its.jnj.com\nEmail: afitzsimmons@bga.bm\nALLAN FITZSIMMONS\nGabriela León Marcano\nLegal Representative\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nETHNOR DEL ISTMO, S.A.\nDate: Oct 10, 2022\nDate: Oct 10, 2022\nEPARTA\nJURIDICO\nNon-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022 ICD Contract ID: 1817854\nEthnor del Istmo, S. A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson'},
#  'Section_56': {'role': 'title', 'content': 'ANNEX C SANCTIONS FORMAT'},
#  'Section_57': {'role': 'title',
#   'content': 'OF THE AGREEMENT FOR THE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES ENTERED BETWEEN ETHNOR AND THE DISTRIBUTOR\nCONTRA CT\nCLIENT\nNAME\nCOMMERC IAL NAME\nAMOUNT REQUESTE D\nUNIT PRICE\nTOTAL AMOU NT OF THE ENTRY\nPURCHASE ORDER CUSTOMER\nDATE OF DELIVER Y PURCHA SE ORDER\nINVOICE JANSSEN\nARRIVAL OF PRODUCT\nREMARKS OR COMMENT S\nDAILY PERCENTA GE OF PENALTY\nDAYS OF SANCTION\nCREDI T NOTE\nTOTAL AMOU NT OF SANCTI ON\nNOTIFICATI ONDATE OF THE SANCTION\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex C and knowing that it is an integral part of the Agreement, we subscribe to it:\nFor DISTRIBUTOR:\nFor ETHNOR DEL ISTMO S.A.\nSignature:\nA. Com\nSignature:\nGabriela Leon Marcano\nEmail: afitzsimmons@bga.bm\nGabriela Leon Marcano (Oct 10, 2022 09:18 CDT)\nEmail: gleonmar@its.jnj.com\nALLAN FITZSIMMONS\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nGabriela León Marcano\nLegal Representative\nDate:\nOct 10. 2022\nDate:\nETHNOR DEL ISTMO, S.A.\nOct 10, 2022\nNon-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_58': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEthnor del Istmo, S. A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson'},
#  'Section_59': {'role': 'sectionHeading',
#   'content': 'ANNEX D DOCUMENTARY REQUIREMENTS FOR REIMBURSEMENT OF SANCTION'},
#  'Section_60': {'role': 'title',
#   'content': 'OF THE AGREEMENT FOR THE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES ENTERED BETWEEN ETHNOR AND THE DISTRIBUTOR\n1. Notification Letter by the DISTRIBUTOR briefly describing the situation\n2. Credit note or copy of check in the name of the Institute which generated the sanction\n3. Notice of the sanction by Institute\n4. Sheet of the contract where the clause thirteenth appears with regards to the penalty\n5. Copy of order of the DISTRIBUTOR\n6. Copy of order of the Institute\n7. Copy of invoice of ETHNOR\n8. ETHNOR notification regarding the shortage of product (if applicable)\n9. Invoice of the Distributor to the Institute\nThe presentation of the mentioned documents does not guarantee the approval and reimbursement thereof.\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex D and knowing that it is an integral part of the Agreement, we subscribe to it:\nFor DISTRIBUTOR:\nFor ETHNOR DEL ISTMO S.A.\nSignature: A.fr\n-\nSignature:\nGabriela Leon Marcano\nGabriela Leon Marcano (Oct 10, 2022 09:18 CDT)\nEmail: afitzsimmons@bga.bm\nEmail: gleonmar@its.jnj.com\nALLAN FITZSIMMONS\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nGabriela León Marcano\nLegal Representative\nETHNOR DEL ISTMO, S.A.\nDate: Oct 10, 2022\nDate:\nOct 10, 2022'},
#  'Section_61': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_62': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEithnor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson'},
#  'Section_63': {'role': 'title',
#   'content': 'ANNEX E MONTHLY INVENTORY FORM (SUGGESTED TEMPLATE)\nOF THE AGREEMENT FOR THE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES ENTERED BETWEEN ETHNOR AND THE DISTRIBUTOR\nJanssen PHARMACEUTICAL COMPANIES OF Johnson &Johnson'},
#  'Section_64': {'role': 'sectionHeading',
#   'content': 'MONTHLY INVENTORY/ ACCUMULATED DEPLACEMENTS\nCode (CB Code )\nProduct description\nStatus\nInstitute\nJanuary\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember\nAccumulated\nJanssen\nPHARMACEUTICAL COMPANIES\nOF Johnson & Johnson\nAS REQUESTED/ ACCUMULATED STOCK IN WHAREHOUSES\nCode (CB Code)\nProduct description\nStorage\nLot\nExpiration date\nTotal Units\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex E and knowing that it is an integral part of the Agreement, we subscribe to it:\nFor DISTRIBUTOR:\nCAr ETUNAD REL ICTMAC A\nSignature: A.fon\nSignature:\nGabriela Leon Marcano\nEmail: afitzsimmons@bga.bm\nGabriela Leon Marcano (Oct 10, 2022 09:18 CDT)\nEmail: gleonmar@its.jnj.com\nALLAN FITZSIMMONS\nLegal Representative\nGabriela León Marcano\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nETHNOR DEL ISTMO, S.A.\nDate:\nOct 10, 2022\nDate:\nOct 10, 2022\nNon-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_65': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEithnor del Istmo, S.A.'},
#  'Section_66': {'role': 'title', 'content': 'ANNEX F'},
#  'Section_67': {'role': 'title',
#   'content': 'TEXT OF LETTER OF SUPPORT FOR BIDDINGS (SUGGESTED TEMPLATE)\nSubject: Public Bid Nº\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson\nDate:\nPublic Entity: Institution/Ministry/ Product:\nThe Institution/Ministry/ will execute the Public Bid in reference the __ of\nof 201 for the acquisition of units of the drug to be delivered as follows:\nunits in days units in days\nsince the receipt of the order or Contract.\nMinimum validity or lifespan: months.\nSignature (Name of authorized person) Date:\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex F and knowing that it is an integral part of the Agreement, we subscribe to it:\nFor DISTRIBUTOR:\nFor ETHNOR DEL ISTMO S.A.\nSignature: A.fr\nEmail: afitzsimmons@bga.bm\n(Price Request)\nSignature:\nGabriela Leon Marcano\nGabriela Leon Marcano (Oct 10, 2022 09:18 CDT)\nEmail: gleonmar@its.jnj.com\nALLAN FITZSIMMONS\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nGabriela León Marcano\nLegal Representative\nETHNOR DEL ISTMO, S.A.\nDate: Oct 10, 2022\nDate: Oct 10, 2022'},
#  'Section_68': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_69': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\nEithnor del Istmo, S.A.\nJanssen\nPHARMACEUTICAL COMPANIES OF Johnson & Johnson'},
#  'Section_70': {'role': 'sectionHeading',
#   'content': 'ANNEX G\nDOCUMENTARY SUPPORT REQUIRED FOR APPROVAL OF REIMBURSEMENT FOR EXPENSES'},
#  'Section_71': {'role': 'title',
#   'content': 'OF THE AGREEMENT FOR THE DISTRIBUTION AND NON-EXCLUSIVE MARKETING OF PRODUCTS FOR THE HEALTH CARE AND GOOD BUSINESS PRACTICES ENTERED BETWEEN ETHNOR AND THE DISTRIBUTOR\nThe Parties agree that ETHNOR will reimburse expenses in respect of the following activities previously authorized in writing by ETHNOR to the DISTRIBUTOR:\n1) Internment of medical samples.\n2) Admission of promotional material.\n3) Payment of health registration processors.\n4) Any other expense not related to the distribution of products previously authorized by ETHNOR to the Distributor.\nElectronic signature. The Parties agree and accept that a signature executed electronically and transmitted electronically will have the full legal force and effect of a handwritten signature, under applicable laws.\nIn full conformity with the contents of this Annex G and knowing that it is an integral part of the Agreement, we subscribe to it:\nFor DISTRIBUTOR:\nFor ETHNOR DEL ISTMO S.A.\nSignature: Atu Email: afitzsimmons@bga.bm\nSignature:\nGabriela Leon Marcano Gabriela Leon Marcano (Oct 10, 2022 09:18 CDT)\nEmail:\ngleonmar@its.jnj.com\nALLAN FITZSIMMONS\nGabriela León Marcano\nLegal Representative\nLegal Representative\nBERMUDA GENERAL AGENCY LTD\nETHNOR DEL ISTMO, S.A.\nDate:\nOct 10, 2022\nDate: Oct 10, 2022'},
#  'Section_72': {'role': 'pageFooter',
#   'content': 'Non-exclusive Distribution Agreement - Bermuda General Agency Ltd BERMUDA - October 2022'},
#  'Section_73': {'role': 'pageFooter',
#   'content': 'ICD Contract ID: 1817854\n[1817854] BGA- New Master Non-Exclusive Distribution Agreement Final Audit Report 2022-10-10\nCreated:\n2022-10-07\nBy:\nJ&J ICD system (icdsup@its.jnj.com)\nStatus:\nSigned\nTransaction ID:\nCBJCHBCAABAA54BbBqORqlqnkanUAd5X3VidAzJ9-SEB\n"[1817854] BGA- New Master Non-Exclusive Distribution Agree ment" History\nDocument created by J&J ICD system (icdsup@its.jnj.com) 2022-10-07 - 3:14:28 PM GMT\nDocument emailed to Allan Fitzsimmons (afitzsimmons@bga.bm) for signature 2022-10-07 - 3:19:42 PM GMT\nEmail viewed by Allan Fitzsimmons (afitzsimmons@bga.bm) 2022-10-07 - 3:20:06 PM GMT\nDocument e-signed by Allan Fitzsimmons (afitzsimmons@bga.bm) Signature Date: 2022-10-10 - 2:10:14 PM GMT - Time Source: server\nDocument emailed to Gabriela Leon Marcano (gleonmar@its.jnj.com) for signature 2022-10-10 - 2:10:18 PM GMT\nEmail viewed by Gabriela Leon Marcano (gleonmar@its.jnj.com) 2022-10-10 - 2:18:10 PM GMT\nDocument e-signed by Gabriela Leon Marcano (gleonmar@its.jnj.com) Signature Date: 2022-10-10 - 2:18:47 PM GMT - Time Source: server\n:selected: Agreement completed. 2022-10-10 - 2:18:47 PM GMT\n:selected:\nAdobe Acrobat Sign'}}

# %%
# Analyze tables
def analyze_table(result):
    tables = {f'table_{i}': '' for i in range(len(result.tables))}

    if result.tables:

        for table_idx, table in enumerate(result.tables):
            rows = {f'row_{i}': '' for i in range(table.row_count)}
            print(f"Table #{table_idx} has {table.row_count} rows and {table.column_count} columns")

            if table.bounding_regions:
                for region in table.bounding_regions:
                    print(f"\t>>> Table #{table_idx} location on page: {region.page_number} is {region.polygon}")

            # Evaluate the cells
            for cell in table.cells:
                rows[f'row_{cell.row_index}'] = {f'col_{cell.column_index}': cell.content}
                print(f"\t>>> Cell [{cell.row_index}][{cell.column_index}] has text '{cell.content}'")
                if cell.bounding_regions:
                    print(f"\t>>> Content on page {region.page_number} is within bounding polygon {region.polygon}")

            tables[f'table_{table_idx}'] = rows
    
    return tables

# %%
analyze_table(result)
# Out:
# Table #0 has 3 rows and 2 columns
# 	>>> Table #0 location on page: 17 is [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [0][0] has text 'INCOTERM'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [0][1] has text 'Acceptance of merchandise and transfer of ownership'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [1][0] has text 'EXW - [Ex Works] Local Sales (warehouse APP)'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [1][1] has text 'For local sales in which the DISTRIBUTOR withdraws the merchandise in the warehouse, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect when said products leave ETHNOR's warehouse. ETHNOR will send the DISTRIBUTOR a copy of the dispatch documentation by email.'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [2][0] has text 'FCA [Free Carrier] Local Sales (delivery in fiscal territory)'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# 	>>> Cell [2][1] has text 'For local sales in which the merchandise is delivered to the DISTRIBUTOR within the relevant territory, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and when the products have been delivered to the main carrier. ETHNOR will send the DISTRIBUTOR a copy of the dispatch documentation by email.'
# 	>>> Content on page 17 is within bounding polygon [1.9788, 6.3239, 7.4243, 6.329, 7.4186, 9.5397, 1.9741, 9.5343]
# Table #1 has 3 rows and 2 columns
# 	>>> Table #1 location on page: 18 is [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [0][0] has text 'INCOTERM'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [0][1] has text 'Acceptance of merchandise and transfer of ownership'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [1][0] has text 'CIP - [Carriage and Insurance Paid to] International or Export Sales'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [1][1] has text 'For export sales for which shipments are made by air, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and the products have been delivered to the airline and the airline issues the Air Waybill or equivalent document that certifies that the time for the products to leave for the country of destination is pending. ETHNOR must send the DISTRIBUTOR a copy of the documentation that will include the dispatch tracking waybill, by email.'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [2][0] has text 'CIF - [Cost, Insurance and Freight] International or export sales - specific for maritime shipments'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# 	>>> Cell [2][1] has text 'For export sales in which shipment of product is made by sea, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and when the products have been delivered and loaded on board the ship at the port of shipment and the maritime transport company issues the receipt of cargo for shipment of the products/ Bill of Lading or equivalent document stating that the time for the products to leave for the country of destination is pending. ETHNOR must send the DISTRIBUTOR a copy of said document by email.'
# 	>>> Content on page 18 is within bounding polygon [1.8908, 3.1486, 7.4193, 3.1532, 7.4177, 7.673, 1.8903, 7.6684]
# Table #2 has 27 rows and 3 columns
# 	>>> Table #2 location on page: 21 is [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [0][0] has text 'Material'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [0][1] has text 'Material'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [0][2] has text 'Amount'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [1][0] has text '378898'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [1][1] has text 'AMOEBRIZ 300MG+150MG 2 TABL. PANAMA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [1][2] has text '9.04'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [2][0] has text '417217'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [2][1] has text 'AMOEBRIZ* 300MG+150MG C/2 TAB MM CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [2][2] has text '1.26'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [3][0] has text '414488'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [3][1] has text 'CONCERTA 18MG 30 OR.TABL. BOTTLE CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [3][2] has text '30.97'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [4][0] has text '414489'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [4][1] has text 'CONCERTA 27MG 30 OR.TABL. BOTTLE CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [4][2] has text '59.52'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [5][0] has text '414490'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [5][1] has text 'CONCERTA 36MG 30 OR.TABL. BOTTLE CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [5][2] has text '61.95'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [6][0] has text '414491'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [6][1] has text 'CONCERTA 54MG 30 OR.TABL. BOTTLE CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [6][2] has text '72.57'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [7][0] has text '416257'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [7][1] has text 'DACOGEN IV 1X50MG VIAL CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [7][2] has text '1,683.35'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [8][0] has text '386146'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [8][1] has text 'DAKTARIN 2% 1X30G CREAM PAN-CAR'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [8][2] has text '7.20'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [9][0] has text '386073'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [9][1] has text 'DAKTARIN 2% 1X78G ORGEL PANAMA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [9][2] has text '14.42'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [10][0] has text '418880'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [10][1] has text 'DARZALEX 1X100MG VIAL CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [10][2] has text '400.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [11][0] has text '457185'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [11][1] has text 'DARZALEX 1X100MG VIAL SCHFVFL2 CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [11][2] has text '400.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [12][0] has text '418476'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [12][1] has text 'DARZALEX 1X400MG VIAL CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [12][2] has text '1,600.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [13][0] has text '419354'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [13][1] has text 'DARZALEX 1X400MG VIAL SCHVFL2 CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [13][2] has text '1,600.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [14][0] has text '416176'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [14][1] has text 'DUROGESIC MATRIX 100MU 5 TRPAT CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [14][2] has text '135.21'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [15][0] has text '416173'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [15][1] has text 'DUROGESIC MATRIX 25MU 5 TRPAT CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [15][2] has text '45.45'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [16][0] has text '416174'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [16][1] has text 'DUROGESIC MATRIX 50MU 5 TRPAT CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [16][2] has text '79.54'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [17][0] has text '416175'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [17][1] has text 'DUROGESIC MATRIX 75MU 5 TRPAT CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [17][2] has text '89.76'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [18][0] has text '95834'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [18][1] has text 'ELEQUINE 500MG 24 TABL. PANAMA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [18][2] has text '80.91'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [19][0] has text '386097'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [19][1] has text 'ELEQUINE 500MG 7 TABL. PANAMA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [19][2] has text '27.30'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [20][0] has text '386099'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [20][1] has text 'ELEQUINE 750MG 5 TABL. PANAMA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [20][2] has text '29.25'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [21][0] has text '417212'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [21][1] has text 'ELEQUINE*750 MG C/5 TAB MM CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [21][2] has text '16.20'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [22][0] has text '416147'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [22][1] has text 'EPREX PROTECS 10000U 1X1ML SYR. CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [22][2] has text '58.61'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [23][0] has text '416149'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [23][1] has text 'EPREX PROTECS 1000U 1X0.5ML SYR. CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [23][2] has text '9.30'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [24][0] has text '416148'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [24][1] has text 'EPREX PROTECS 40000U 1X1ML SYR CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [24][2] has text '412.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [25][0] has text '416146'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [25][1] has text 'EPREX PROTECS 4000U 6X0.4ML SYR. CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [25][2] has text '140.55'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [26][0] has text '419222'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [26][1] has text 'ERLEADA 60MG 120 TABL. CENCA'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# 	>>> Cell [26][2] has text '3,900.00'
# 	>>> Content on page 21 is within bounding polygon [0.9872, 4.267, 6.1099, 4.2746, 6.1046, 9.9463, 0.9829, 9.9383]
# Table #3 has 41 rows and 3 columns
# 	>>> Table #3 location on page: 22 is [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [0][0] has text '416538'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [0][1] has text 'EVRA 1X3 PATCH CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [0][2] has text '22.17'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [1][0] has text '386167'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [1][1] has text 'GYNO DAKTARIN 2% 1X78G CREAM PAN-CAR'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [1][2] has text '9.62'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [2][0] has text '386090'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [2][1] has text 'HALDOL 5MG 20 TABL. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [2][2] has text '10.39'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [3][0] has text '418066'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [3][1] has text 'IMBRUVICA 140MG 90 CAPS. IND.A-CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [3][2] has text '6,000.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [4][0] has text '386153'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [4][1] has text 'IMODIUM 2MG 12 CAPS. PAN-CAR'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [4][2] has text '5.79'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [5][0] has text '386096'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [5][1] has text 'IMODIUM 2MG 60 CAPS. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [5][2] has text '25.95'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [6][0] has text '416205'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [6][1] has text 'INTELENCE 100MG 120 TABL. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [6][2] has text '584.01'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [7][0] has text '418436'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [7][1] has text 'INVEGA 3MG 7 TABL. ALU ALU CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [7][2] has text '42.60'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [8][0] has text '418437'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [8][1] has text 'INVEGA 6MG 28 TABL. ALU ALU CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [8][2] has text '156.78'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [9][0] has text '418435'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [9][1] has text 'INVEGA 6MG 7 TABL. ALU ALU CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [9][2] has text '42.60'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [10][0] has text '414698'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [10][1] has text 'INVEGA SUSTENNA 1X100MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [10][2] has text '410.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [11][0] has text '414699'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [11][1] has text 'INVEGA SUSTENNA 1X150MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [11][2] has text '410.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [12][0] has text '419193'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [12][1] has text 'INVEGA SUSTENNA 1X50MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [12][2] has text '215.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [13][0] has text '414697'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [13][1] has text 'INVEGA SUSTENNA 1X75MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [13][2] has text '320.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [14][0] has text '418481'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [14][1] has text 'INVEGA TRINZA 1X175MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [14][2] has text '645.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [15][0] has text '418482'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [15][1] has text 'INVEGA TRINZA 1X263MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [15][2] has text '960.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [16][0] has text '418483'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [16][1] has text 'INVEGA TRINZA 1X350MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [16][2] has text '1,230.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [17][0] has text '418484'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [17][1] has text 'INVEGA TRINZA 1X525MG SYR. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [17][2] has text '1,230.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [18][0] has text '418076'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [18][1] has text 'INVOKANA 100MG 30 FC.TABL. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [18][2] has text '54.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [19][0] has text '418077'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [19][1] has text 'INVOKANA 300MG 30 FC.TABL. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [19][2] has text '54.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [20][0] has text '386102'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [20][1] has text 'MOTILIUM 10MG 30 FC.TABL. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [20][2] has text '8.29'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [21][0] has text '382282'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [21][1] has text 'MOTILIUM 1MG/ML 1X60ML SUSP. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [21][2] has text '11.05'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [22][0] has text '385275'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [22][1] has text 'MOTILIUM* 10mg C/2 MM C.A.'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [22][2] has text '0.51'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [23][0] has text '386106'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [23][1] has text 'NIZORAL 2% 1X100ML SHAMP PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [23][2] has text '12.05'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [24][0] has text '386111'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [24][1] has text 'NIZORAL 2% 1X40G CREAM PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [24][2] has text '11.22'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [25][0] has text '386104'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [25][1] has text 'NIZORAL 400MG 3 OVULS PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [25][2] has text '11.52'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [26][0] has text '385276'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [26][1] has text 'NIZORAL* 5G CREMA MM EXP CA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [26][2] has text '0.71'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [27][0] has text '416245'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [27][1] has text 'PREZISTA 600MG 60 FC.TABL. CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [27][2] has text '540.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [28][0] has text '412677'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [28][1] has text 'REMICADE 1X100MG VIAL CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [28][2] has text '504.06'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [29][0] has text '382312'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [29][1] has text 'REMINYL ER 16MG 7 CAPS. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [29][2] has text '37.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [30][0] has text '382311'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [30][1] has text 'REMINYL ER 8MG 7 CAPS. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [30][2] has text '37.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [31][0] has text '386180'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [31][1] has text 'RETIN-A 0.25MG/G 1X40G CREAM PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [31][2] has text '11.19'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [32][0] has text '386181'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [32][1] has text 'RETIN-A 0.5MG/G 1X40G CREAM PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [32][2] has text '11.08'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [33][0] has text '386179'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [33][1] has text 'RETIN-A 1MG/G 1X40G CREAM PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [33][2] has text '15.80'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [34][0] has text '386182'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [34][1] has text 'RETIN-A* GEL 0.01% 40G CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [34][2] has text '10.71'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [35][0] has text '418429'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [35][1] has text 'RIBOMUSTIN 1X100MG VIAL ONCOTEC CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [35][2] has text '750.00'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [36][0] has text '418259'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [36][1] has text 'RIBOMUSTIN 1X25MG VIAL ONCOTEC CENCA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [36][2] has text '187.50'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [37][0] has text '386119'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [37][1] has text 'RISPERDAL 1MG 20 FC.TABL. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [37][2] has text '17.90'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [38][0] has text '386116'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [38][1] has text 'RISPERDAL 1MG/ML 1X60ML SOLUT. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [38][2] has text '53.53'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [39][0] has text '386121'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [39][1] has text 'RISPERDAL 2MG 20 FC.TABL. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [39][2] has text '35.79'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [40][0] has text '386123'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [40][1] has text 'RISPERDAL 3MG 20 FC.TABL. PANAMA'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# 	>>> Cell [40][2] has text '53.64'
# 	>>> Content on page 22 is within bounding polygon [0.9921, 1.4685, 6.1101, 1.4806, 6.1003, 10.0507, 0.9831, 10.0388]
# Table #4 has 36 rows and 3 columns
# 	>>> Table #4 location on page: 23 is [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [0][0] has text '418447'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [0][1] has text 'RISPERDAL CONSTA 1X37.5MG KIT CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [0][2] has text '142.80'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [1][0] has text '414713'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [1][1] has text 'SIMPONI 1X50MG AUTOINJ. VEN-CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [1][2] has text '1,400.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [2][0] has text '386128'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [2][1] has text 'SPORANOX 100MG 15 CAPS. PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [2][2] has text '31.80'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [3][0] has text '385290'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [3][1] has text 'SPORANOX* CAP 100MG C/1 MM CA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [3][2] has text '1.14'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [4][0] has text '386129'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [4][1] has text 'SPORASEC 12 CAPS. PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [4][2] has text '18.25'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [5][0] has text '87070'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [5][1] has text 'SPORASEC* C/2 MM CA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [5][2] has text '0.90'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [6][0] has text '457442'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [6][1] has text 'SPRAVATO 1X28MG NASPR. CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [6][2] has text '210.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [7][0] has text '457443'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [7][1] has text 'SPRAVATO 2X28MG NASPR. CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [7][2] has text '420.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [8][0] has text '457444'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [8][1] has text 'SPRAVATO 3X28MG NASPR. CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [8][2] has text '630.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [9][0] has text '416462'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [9][1] has text 'STELARA 1X45MG SYR. CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [9][2] has text '3,700.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [10][0] has text '414712'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [10][1] has text 'STELARA 1X45MG VIAL CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [10][2] has text '3,700.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [11][0] has text '418697'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [11][1] has text 'STELARA 1X90MG SYR. CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [11][2] has text '3,700.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [12][0] has text '418988'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [12][1] has text 'STELARA IV 1X130MG VIAL CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [12][2] has text '1,600.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [13][0] has text '86652'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [13][1] has text 'STUGERON FORTE 75MG 60 TABL. L-AMER.'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [13][2] has text '21.58'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [14][0] has text '417214'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [14][1] has text 'STUGERON FORTE* 75MG C/10 TAB MM CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [14][2] has text '2.74'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [15][0] has text '83533'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [15][1] has text 'SUFREXAL 2% 1X78G GEL C-AMER.'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [15][2] has text '25.75'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [16][0] has text '386132'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [16][1] has text 'SUFREXAL VAG. 2% 1X78G GEL PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [16][2] has text '24.94'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [17][0] has text '417215'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [17][1] has text 'SUFREXAL* 2% 1X5G GEL MM CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [17][2] has text '1.00'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [18][0] has text '386185'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [18][1] has text 'TOPAMAX 100MG 20 TABL. PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [18][2] has text '31.32'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [19][0] has text '386186'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [19][1] has text 'TOPAMAX 25MG 20 TABL. PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [19][2] has text '9.73'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [20][0] has text '387680'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [20][1] has text 'TRAMACET 37.5MG 40 TABL. PANAMA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [20][2] has text '22.04'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [21][0] has text '417216'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [21][1] has text 'TRAMACET* 37.5 MG C/2 TAB MM CENCA'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [21][2] has text '0.47'
# 	>>> Content on page 23 is within bounding polygon [0.9905, 1.4711, 6.1123, 1.4825, 6.1041, 9.0089, 0.983, 8.9978]
# 	>>> Cell [22][0] has text '419131'
# ...
# 	>>> Cell [0][14] has text 'November'
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [0][15] has text 'December'
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [0][16] has text 'Accumulated'
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][0] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][1] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][2] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][3] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][4] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][5] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][6] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][7] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][8] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][9] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][10] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][11] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][12] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][13] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][14] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][15] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# 	>>> Cell [1][16] has text ''
# 	>>> Content on page 29 is within bounding polygon [0.9909, 3.9128, 7.5102, 3.914, 7.5073, 4.4744, 0.9888, 4.4732]
# Table #8 has 2 rows and 6 columns
# 	>>> Table #8 location on page: 29 is [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][0] has text 'Code (CB Code)'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][1] has text 'Product description'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][2] has text 'Storage'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][3] has text 'Lot'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][4] has text 'Expiration date'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [0][5] has text 'Total Units'
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][0] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][1] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][2] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][3] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][4] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# 	>>> Cell [1][5] has text ''
# 	>>> Content on page 29 is within bounding polygon [1.4859, 5.4069, 7.5004, 5.41, 7.498, 6.2608, 1.4842, 6.2579]
# Table #9 has 7 rows and 4 columns
# 	>>> Table #9 location on page: 31 is [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [0][0] has text 'For DISTRIBUTOR:'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [0][2] has text 'For ETHNOR DEL ISTMO S.A.'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [1][0] has text 'Signature: Atu Email: afitzsimmons@bga.bm'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [1][2] has text 'Signature:'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [1][3] has text 'Gabriela Leon Marcano Gabriela Leon Marcano (Oct 10, 2022 09:18 CDT)'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [2][2] has text 'Email:'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [2][3] has text 'gleonmar@its.jnj.com'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [3][0] has text ''
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [3][1] has text 'ALLAN FITZSIMMONS'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [3][2] has text 'Gabriela León Marcano'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [4][0] has text ''
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [4][1] has text 'Legal Representative'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [4][2] has text 'Legal Representative'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [5][0] has text 'BERMUDA GENERAL AGENCY LTD'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [5][2] has text 'ETHNOR DEL ISTMO, S.A.'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [6][0] has text 'Date:
# Oct 10, 2022'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# 	>>> Cell [6][2] has text 'Date: Oct 10, 2022'
# 	>>> Content on page 31 is within bounding polygon [0.6491, 6.3129, 7.45, 6.3115, 7.4643, 7.8719, 0.6671, 7.8739]
# Table #10 has 4 rows and 2 columns
# 	>>> Table #10 location on page: 32 is [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [0][0] has text 'Created:'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [0][1] has text '2022-10-07'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [1][0] has text 'By:'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [1][1] has text 'J&J ICD system (icdsup@its.jnj.com)'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [2][0] has text 'Status:'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [2][1] has text 'Signed'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [3][0] has text 'Transaction ID:'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# 	>>> Cell [3][1] has text 'CBJCHBCAABAA54BbBqORqlqnkanUAd5X3VidAzJ9-SEB'
# 	>>> Content on page 32 is within bounding polygon [0.6722, 1.6538, 7.9141, 1.6563, 7.9112, 2.8964, 0.6715, 2.8934]
# {'table_0': {'row_0': {'col_1': 'Acceptance of merchandise and transfer of ownership'},
#   'row_1': {'col_1': "For local sales in which the DISTRIBUTOR withdraws the merchandise in the warehouse, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect when said products leave ETHNOR's warehouse. ETHNOR will send the DISTRIBUTOR a copy of the dispatch documentation by email."},
#   'row_2': {'col_1': 'For local sales in which the merchandise is delivered to the DISTRIBUTOR within the relevant territory, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and when the products have been delivered to the main carrier. ETHNOR will send the DISTRIBUTOR a copy of the dispatch documentation by email.'}},
#  'table_1': {'row_0': {'col_1': 'Acceptance of merchandise and transfer of ownership'},
#   'row_1': {'col_1': 'For export sales for which shipments are made by air, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and the products have been delivered to the airline and the airline issues the Air Waybill or equivalent document that certifies that the time for the products to leave for the country of destination is pending. ETHNOR must send the DISTRIBUTOR a copy of the documentation that will include the dispatch tracking waybill, by email.'},
#   'row_2': {'col_1': 'For export sales in which shipment of product is made by sea, THE PARTIES agree that the transfer and acceptance of ownership of the products will take effect once the export procedures have been completed and when the products have been delivered and loaded on board the ship at the port of shipment and the maritime transport company issues the receipt of cargo for shipment of the products/ Bill of Lading or equivalent document stating that the time for the products to leave for the country of destination is pending. ETHNOR must send the DISTRIBUTOR a copy of said document by email.'}},
#  'table_2': {'row_0': {'col_2': 'Amount'},
#   'row_1': {'col_2': '9.04'},
#   'row_2': {'col_2': '1.26'},
#   'row_3': {'col_2': '30.97'},
#   'row_4': {'col_2': '59.52'},
#   'row_5': {'col_2': '61.95'},
#   'row_6': {'col_2': '72.57'},
#   'row_7': {'col_2': '1,683.35'},
#   'row_8': {'col_2': '7.20'},
#   'row_9': {'col_2': '14.42'},
#   'row_10': {'col_2': '400.00'},
#   'row_11': {'col_2': '400.00'},
#   'row_12': {'col_2': '1,600.00'},
#   'row_13': {'col_2': '1,600.00'},
#   'row_14': {'col_2': '135.21'},
#   'row_15': {'col_2': '45.45'},
#   'row_16': {'col_2': '79.54'},
#   'row_17': {'col_2': '89.76'},
#   'row_18': {'col_2': '80.91'},
#   'row_19': {'col_2': '27.30'},
#   'row_20': {'col_2': '29.25'},
#   'row_21': {'col_2': '16.20'},
#   'row_22': {'col_2': '58.61'},
#   'row_23': {'col_2': '9.30'},
#   'row_24': {'col_2': '412.00'},
#   'row_25': {'col_2': '140.55'},
#   'row_26': {'col_2': '3,900.00'}},
#  'table_3': {'row_0': {'col_2': '22.17'},
#   'row_1': {'col_2': '9.62'},
#   'row_2': {'col_2': '10.39'},
#   'row_3': {'col_2': '6,000.00'},
#   'row_4': {'col_2': '5.79'},
#   'row_5': {'col_2': '25.95'},
#   'row_6': {'col_2': '584.01'},
#   'row_7': {'col_2': '42.60'},
#   'row_8': {'col_2': '156.78'},
#   'row_9': {'col_2': '42.60'},
#   'row_10': {'col_2': '410.00'},
#   'row_11': {'col_2': '410.00'},
#   'row_12': {'col_2': '215.00'},
#   'row_13': {'col_2': '320.00'},
#   'row_14': {'col_2': '645.00'},
#   'row_15': {'col_2': '960.00'},
#   'row_16': {'col_2': '1,230.00'},
#   'row_17': {'col_2': '1,230.00'},
#   'row_18': {'col_2': '54.00'},
#   'row_19': {'col_2': '54.00'},
#   'row_20': {'col_2': '8.29'},
#   'row_21': {'col_2': '11.05'},
#   'row_22': {'col_2': '0.51'},
#   'row_23': {'col_2': '12.05'},
#   'row_24': {'col_2': '11.22'},
#   'row_25': {'col_2': '11.52'},
#   'row_26': {'col_2': '0.71'},
#   'row_27': {'col_2': '540.00'},
#   'row_28': {'col_2': '504.06'},
#   'row_29': {'col_2': '37.00'},
#   'row_30': {'col_2': '37.00'},
#   'row_31': {'col_2': '11.19'},
#   'row_32': {'col_2': '11.08'},
#   'row_33': {'col_2': '15.80'},
#   'row_34': {'col_2': '10.71'},
#   'row_35': {'col_2': '750.00'},
#   'row_36': {'col_2': '187.50'},
#   'row_37': {'col_2': '17.90'},
#   'row_38': {'col_2': '53.53'},
#   'row_39': {'col_2': '35.79'},
#   'row_40': {'col_2': '53.64'}},
#  'table_4': {'row_0': {'col_2': '142.80'},
#   'row_1': {'col_2': '1,400.00'},
#   'row_2': {'col_2': '31.80'},
#   'row_3': {'col_2': '1.14'},
#   'row_4': {'col_2': '18.25'},
#   'row_5': {'col_2': '0.90'},
#   'row_6': {'col_2': '210.00'},
#   'row_7': {'col_2': '420.00'},
#   'row_8': {'col_2': '630.00'},
#   'row_9': {'col_2': '3,700.00'},
#   'row_10': {'col_2': '3,700.00'},
#   'row_11': {'col_2': '3,700.00'},
#   'row_12': {'col_2': '1,600.00'},
#   'row_13': {'col_2': '21.58'},
#   'row_14': {'col_2': '2.74'},
#   'row_15': {'col_2': '25.75'},
#   'row_16': {'col_2': '24.94'},
#   'row_17': {'col_2': '1.00'},
#   'row_18': {'col_2': '31.32'},
#   'row_19': {'col_2': '9.73'},
#   'row_20': {'col_2': '22.04'},
#   'row_21': {'col_2': '0.47'},
#   'row_22': {'col_2': '2,000.00'},
#   'row_23': {'col_2': '5.25'},
#   'row_24': {'col_2': '9.68'},
#   'row_25': {'col_2': '0.40'},
#   'row_26': {'col_2': '7.61'},
#   'row_27': {'col_2': '7.61'},
#   'row_28': {'col_2': '1,296.00'},
#   'row_29': {'col_2': '1,296.00'},
#   'row_30': {'col_2': '54.00'},
#   'row_31': {'col_2': '54.00'},
#   'row_32': {'col_2': '54.00'},
#   'row_33': {'col_2': '54.00'},
#   'row_34': {'col_2': '3,900.00'},
#   'row_35': {'col_2': '3,900.00'}},
#  'table_5': {'row_0': {'col_1': 'For ETHNOR DEL ISTMO S.A.'},
#   'row_1': {'col_1': 'Gabriela Leon Marcano\nSignature: Gabriela Leon Marcano (Oct 10, 2022 09:18 CDT) Email: gleonmar@its.jnj.com'},
#   'row_2': {'col_0': 'Email: afitzsimmons@bga.bm'},
#   'row_3': {'col_1': 'Gabriela León Marcano'},
#   'row_4': {'col_1': 'Legal Representative'},
#   'row_5': {'col_1': 'ETHNOR DEL ISTMO, S.A.'},
#   'row_6': {'col_1': 'Date: Oct 10, 2022'}},
#  'table_6': {'row_0': {'col_8': 'DATE OF DELIVER Y PURCHA SE ORDER'},
#   'row_1': {'col_8': ''},
#   'row_2': {'col_8': ''}},
#  'table_7': {'row_0': {'col_16': 'Accumulated'}, 'row_1': {'col_16': ''}},
#  'table_8': {'row_0': {'col_5': 'Total Units'}, 'row_1': {'col_5': ''}},
#  'table_9': {'row_0': {'col_2': 'For ETHNOR DEL ISTMO S.A.'},
#   'row_1': {'col_3': 'Gabriela Leon Marcano Gabriela Leon Marcano (Oct 10, 2022 09:18 CDT)'},
#   'row_2': {'col_3': 'gleonmar@its.jnj.com'},
#   'row_3': {'col_2': 'Gabriela León Marcano'},
#   'row_4': {'col_2': 'Legal Representative'},
#   'row_5': {'col_2': 'ETHNOR DEL ISTMO, S.A.'},
#   'row_6': {'col_2': 'Date: Oct 10, 2022'}},
#  'table_10': {'row_0': {'col_1': '2022-10-07'},
#   'row_1': {'col_1': 'J&J ICD system (icdsup@its.jnj.com)'},
#   'row_2': {'col_1': 'Signed'},
#   'row_3': {'col_1': 'CBJCHBCAABAA54BbBqORqlqnkanUAd5X3VidAzJ9-SEB'}}}

# %%
def crop_image_from_image(image_path, page_number, bounding_box):
    with Image.open(image_path) as img:
        if img.format == "TIFF":
            img.seek(page_number)
            img = img.copy()

        return img.crop(bounding_box)

# %%
def crop_image_from_pdf_page(pdf_path, page_number, bounding_box):
    doc = fitz.open(pdf_path)
    page = doc.load_page(page_number)

    bbx = [x * 72 for x in bounding_box]
    rect = fitz.Rect(bbx)
    pix = page.get_pixmap(matrix = fitz.Matrix(300/72, 300/72),
                          clip = rect)
    img = Image.frombytes("RGB",
                          [pix.width, pix.height],
                          pix.samples)
    doc.close()

    return img

# %%
def crop_image_from_file(file_path, page_number, bounding_box):
    mime_type = mimetypes.guess_type(file_path)[0]

    if mime_type == "application/pdf":
        return crop_image_from_pdf_page(file_path, page_number, bounding_box)
    else:
        return crop_image_from_image(file_path, page_number, bounding_box)

# %%
# Analyze the text from figures
# https://github.com/Azure-Samples/document-intelligence-code-samples/blob/main/Python(v4.0)/Retrieval_Augmented_Generation_(RAG)_samples/sample_figure_understanding.ipynb
def get_figures(result, file_path):
    images = {f"img_{i}": '' for i in range(len(result.figures))}
    content = result.content

    if result.figures:
        print(f"Found {len(result.figures)} figures.")

        for figures_idx, figures in enumerate(result.figures):
            fig_content = ''
            img_desc = ''
            print(f"\t>>> Figure #{figures_idx} has the following spans: {figures.spans}")

            for i, span in enumerate(figures.spans):
                print(f"\t>>> Span #{i}: {span}")
                fig_content += content[span.offset:span.offset + span.length]
            print(f"\t>>> Original figure content in markdown: {fig_content}")

            # The figure bounding boxes includes the coordinates of both the image and the caption
            if figures.caption:
                caption_region = figures.caption.bounding_regions
                print(f"\t>>> Caption: {figures.caption.content}")
                print(f"\t>>> Caption bounding region: {caption_region}")

                for region in figures.bounding_regions:
                    if region not in caption_region:
                        print(f"\t>>> Figure body bounding regions: {region}")
                        bounding_box = (region.polygon[0], #x0 (left)
                                        region.polygon[1], #y0 (top)
                                        region.polygon[4], #x1 (right)
                                        region.polygon[5]) #y1 (bottom)
                        print(f"\t>>> Figure body bounding box in: {bounding_box}")
                        cropped_image = crop_image_from_file(file_path, region.page_number-1, bounding_box)

                        images[f"img_{figures_idx}"] = cropped_image
            else:
                print("\t>>> No caption found for this figure")

                for region in figures.bounding_regions:
                    print(f"\t>>> Figure body bounding regions: {region}")
                    bounding_box = (region.polygon[0], #x0 (left)
                                    region.polygon[1], #y0 (top)
                                    region.polygon[4], #x1 (right)
                                    region.polygon[5]) #y1 (bottom)
                    print(f"\t>>> Figure body bounding box in: {bounding_box}")
                    cropped_image = crop_image_from_file(file_path, region.page_number-1, bounding_box)

                    images[f"img_{figures_idx}"] = cropped_image
                    
    print(images)
    return images

# %%
def save_images(images, filename, save_path):
    for key, value in images.items():
        base_name = key
        output_file = base_name + '.png'
        img_path = os.path.join(save_path, '_'.join([filename, output_file]))

        value.save(img_path)
        print(f"{img_path} image saved!")

# %%
images = get_figures(result, file_path)
save_images(images, filename.rsplit('.pdf', 1)[0], base_path)
# Out:
# Found 60 figures.
# 	>>> Figure #0 has the following spans: [{'offset': 0, 'length': 22}]
# 	>>> Span #0: {'offset': 0, 'length': 22}
# 	>>> Original figure content in markdown: Lithor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 1, 'polygon': [1.1112, 1.117, 3.7053, 1.1166, 3.7058, 1.4212, 1.1117, 1.4216]}
# 	>>> Figure body bounding box in: (1.1112, 1.117, 3.7058, 1.4212)
# 	>>> Figure #1 has the following spans: [{'offset': 23, 'length': 53}]
# 	>>> Span #0: {'offset': 23, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 1, 'polygon': [4.5649, 0.7136, 7.3022, 0.7136, 7.3019, 1.2798, 4.5649, 1.2796]}
# 	>>> Figure body bounding box in: (4.5649, 0.7136, 7.3019, 1.2798)
# 	>>> Figure #2 has the following spans: [{'offset': 3301, 'length': 53}]
# 	>>> Span #0: {'offset': 3301, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 2, 'polygon': [4.5633, 0.7126, 7.3014, 0.7125, 7.3012, 1.2784, 4.5633, 1.2783]}
# 	>>> Figure body bounding box in: (4.5633, 0.7126, 7.3012, 1.2784)
# 	>>> Figure #3 has the following spans: [{'offset': 3355, 'length': 23}]
# 	>>> Span #0: {'offset': 3355, 'length': 23}
# 	>>> Original figure content in markdown: Tithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 2, 'polygon': [1.1072, 1.1149, 3.7077, 1.1147, 3.7085, 1.4252, 1.1081, 1.4254]}
# 	>>> Figure body bounding box in: (1.1072, 1.1149, 3.7085, 1.4252)
# 	>>> Figure #4 has the following spans: [{'offset': 6631, 'length': 23}]
# 	>>> Span #0: {'offset': 6631, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Jstma, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 3, 'polygon': [1.1186, 1.1232, 3.7038, 1.1235, 3.7031, 1.4214, 1.1181, 1.4211]}
# 	>>> Figure body bounding box in: (1.1186, 1.1232, 3.7031, 1.4214)
# 	>>> Figure #5 has the following spans: [{'offset': 10768, 'length': 7}]
# 	>>> Span #0: {'offset': 10768, 'length': 7}
# 	>>> Original figure content in markdown: Janssen
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 3, 'polygon': [4.5639, 0.711, 5.8976, 0.7114, 5.8977, 1.2746, 4.5639, 1.2742]}
# 	>>> Figure body bounding box in: (4.5639, 0.711, 5.8977, 1.2746)
# 	>>> Figure #6 has the following spans: [{'offset': 10841, 'length': 4}]
# 	>>> Span #0: {'offset': 10841, 'length': 4}
# 	>>> Original figure content in markdown: S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 4, 'polygon': [3.0824, 1.1507, 3.7026, 1.1508, 3.702, 1.4181, 3.0819, 1.4179]}
# 	>>> Figure body bounding box in: (3.0824, 1.1507, 3.702, 1.4181)
# 	>>> Figure #7 has the following spans: [{'offset': 14521, 'length': 53}]
# 	>>> Span #0: {'offset': 14521, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 4, 'polygon': [4.5645, 0.711, 7.3008, 0.7108, 7.3008, 1.288, 4.5647, 1.288]}
# 	>>> Figure body bounding box in: (4.5645, 0.711, 7.3008, 1.288)
# 	>>> Figure #8 has the following spans: [{'offset': 14586, 'length': 53}]
# 	>>> Span #0: {'offset': 14586, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 5, 'polygon': [4.5641, 0.7147, 7.3019, 0.7145, 7.3015, 1.2752, 4.564, 1.2751]}
# 	>>> Figure body bounding box in: (4.5641, 0.7147, 7.3015, 1.2752)
# 	>>> Figure #9 has the following spans: [{'offset': 18621, 'length': 4}]
# 	>>> Span #0: {'offset': 18621, 'length': 4}
# 	>>> Original figure content in markdown: S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 6, 'polygon': [3.085, 1.1459, 3.7032, 1.146, 3.7028, 1.4153, 3.0846, 1.4151]}
# 	>>> Figure body bounding box in: (3.085, 1.1459, 3.7028, 1.4153)
# 	>>> Figure #10 has the following spans: [{'offset': 18626, 'length': 53}]
# 	>>> Span #0: {'offset': 18626, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 6, 'polygon': [4.566, 0.7116, 7.3013, 0.7114, 7.3009, 1.2822, 4.5659, 1.2821]}
# 	>>> Figure body bounding box in: (4.566, 0.7116, 7.3009, 1.2822)
# 	>>> Figure #11 has the following spans: [{'offset': 22055, 'length': 53}]
# 	>>> Span #0: {'offset': 22055, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 7, 'polygon': [4.561, 0.7138, 7.2992, 0.7136, 7.2991, 1.2868, 4.561, 1.2867]}
# 	>>> Figure body bounding box in: (4.561, 0.7138, 7.2991, 1.2868)
# 	>>> Figure #12 has the following spans: [{'offset': 22109, 'length': 23}]
# 	>>> Span #0: {'offset': 22109, 'length': 23}
# 	>>> Original figure content in markdown: Fithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 7, 'polygon': [1.1099, 1.1239, 3.7073, 1.1239, 3.7071, 1.4304, 1.1098, 1.4303]}
# 	>>> Figure body bounding box in: (1.1099, 1.1239, 3.7071, 1.4304)
# 	>>> Figure #13 has the following spans: [{'offset': 25859, 'length': 53}]
# 	>>> Span #0: {'offset': 25859, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 8, 'polygon': [4.5631, 0.712, 7.3011, 0.7118, 7.301, 1.2844, 4.5632, 1.2844]}
# 	>>> Figure body bounding box in: (4.5631, 0.712, 7.301, 1.2844)
# 	>>> Figure #14 has the following spans: [{'offset': 29039, 'length': 53}]
# 	>>> Span #0: {'offset': 29039, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 9, 'polygon': [4.5665, 0.7099, 7.2993, 0.7097, 7.2993, 1.2797, 4.5666, 1.2797]}
# 	>>> Figure body bounding box in: (4.5665, 0.7099, 7.2993, 1.2797)
# 	>>> Figure #15 has the following spans: [{'offset': 29093, 'length': 23}]
# 	>>> Span #0: {'offset': 29093, 'length': 23}
# 	>>> Original figure content in markdown: Tithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 9, 'polygon': [1.116, 1.1266, 3.7086, 1.1267, 3.7084, 1.4203, 1.1159, 1.4202]}
# 	>>> Figure body bounding box in: (1.116, 1.1266, 3.7084, 1.4203)
# 	>>> Figure #16 has the following spans: [{'offset': 32152, 'length': 23}]
# 	>>> Span #0: {'offset': 32152, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 10, 'polygon': [1.1075, 1.1249, 3.7036, 1.125, 3.7032, 1.4261, 1.107, 1.4259]}
# 	>>> Figure body bounding box in: (1.1075, 1.1249, 3.7032, 1.4261)
# 	>>> Figure #17 has the following spans: [{'offset': 32176, 'length': 53}]
# 	>>> Span #0: {'offset': 32176, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 10, 'polygon': [4.5667, 0.7113, 7.3029, 0.7112, 7.3029, 1.2772, 4.5669, 1.277]}
# 	>>> Figure body bounding box in: (4.5667, 0.7113, 7.3029, 1.2772)
# 	>>> Figure #18 has the following spans: [{'offset': 35407, 'length': 53}]
# 	>>> Span #0: {'offset': 35407, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 11, 'polygon': [4.5629, 0.7112, 7.2997, 0.7114, 7.2995, 1.2664, 4.563, 1.2661]}
# 	>>> Figure body bounding box in: (4.5629, 0.7112, 7.2995, 1.2664)
# 	>>> Figure #19 has the following spans: [{'offset': 35461, 'length': 23}]
# 	>>> Span #0: {'offset': 35461, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 11, 'polygon': [1.1055, 1.1245, 3.7127, 1.1244, 3.7128, 1.4373, 1.1057, 1.4373]}
# 	>>> Figure body bounding box in: (1.1055, 1.1245, 3.7128, 1.4373)
# 	>>> Figure #20 has the following spans: [{'offset': 38099, 'length': 53}]
# 	>>> Span #0: {'offset': 38099, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 12, 'polygon': [4.5647, 0.7131, 7.3035, 0.713, 7.3034, 1.2748, 4.5648, 1.2747]}
# 	>>> Figure body bounding box in: (4.5647, 0.7131, 7.3034, 1.2748)
# 	>>> Figure #21 has the following spans: [{'offset': 38153, 'length': 23}]
# 	>>> Span #0: {'offset': 38153, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 12, 'polygon': [1.1184, 1.1279, 3.7096, 1.1279, 3.7087, 1.423, 1.1177, 1.423]}
# 	>>> Figure body bounding box in: (1.1184, 1.1279, 3.7087, 1.423)
# 	>>> Figure #22 has the following spans: [{'offset': 41897, 'length': 53}]
# 	>>> Span #0: {'offset': 41897, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 13, 'polygon': [4.5654, 0.7112, 7.3014, 0.7111, 7.3011, 1.2772, 4.5653, 1.2771]}
# 	>>> Figure body bounding box in: (4.5654, 0.7112, 7.3011, 1.2772)
# 	>>> Figure #23 has the following spans: [{'offset': 41951, 'length': 23}]
# 	>>> Span #0: {'offset': 41951, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 13, 'polygon': [1.1132, 1.1234, 3.7063, 1.1237, 3.7057, 1.4263, 1.1127, 1.426]}
# 	>>> Figure body bounding box in: (1.1132, 1.1234, 3.7057, 1.4263)
# 	>>> Figure #24 has the following spans: [{'offset': 45541, 'length': 53}]
# 	>>> Span #0: {'offset': 45541, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 14, 'polygon': [4.563, 0.7121, 7.3014, 0.7121, 7.3013, 1.2824, 4.563, 1.2822]}
# 	>>> Figure body bounding box in: (4.563, 0.7121, 7.3013, 1.2824)
# 	>>> Figure #25 has the following spans: [{'offset': 45595, 'length': 23}]
# 	>>> Span #0: {'offset': 45595, 'length': 23}
# 	>>> Original figure content in markdown: Lithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 14, 'polygon': [1.1079, 1.1166, 3.7076, 1.1161, 3.7081, 1.4241, 1.1084, 1.4244]}
# 	>>> Figure body bounding box in: (1.1079, 1.1166, 3.7081, 1.4241)
# 	>>> Figure #26 has the following spans: [{'offset': 48948, 'length': 4}]
# 	>>> Span #0: {'offset': 48948, 'length': 4}
# 	>>> Original figure content in markdown: S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 15, 'polygon': [3.0865, 1.1431, 3.7074, 1.1433, 3.7069, 1.4149, 3.0862, 1.4146]}
# 	>>> Figure body bounding box in: (3.0865, 1.1431, 3.7069, 1.4149)
# 	>>> Figure #27 has the following spans: [{'offset': 48953, 'length': 53}]
# 	>>> Span #0: {'offset': 48953, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 15, 'polygon': [4.5639, 0.7126, 7.3018, 0.7123, 7.3016, 1.2835, 4.5639, 1.2835]}
# 	>>> Figure body bounding box in: (4.5639, 0.7126, 7.3016, 1.2835)
# 	>>> Figure #28 has the following spans: [{'offset': 52662, 'length': 53}]
# 	>>> Span #0: {'offset': 52662, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 16, 'polygon': [4.5652, 0.7091, 7.2999, 0.7089, 7.2999, 1.2862, 4.5653, 1.2861]}
# 	>>> Figure body bounding box in: (4.5652, 0.7091, 7.2999, 1.2862)
# 	>>> Figure #29 has the following spans: [{'offset': 52716, 'length': 23}]
# 	>>> Span #0: {'offset': 52716, 'length': 23}
# 	>>> Original figure content in markdown: Lithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 16, 'polygon': [1.1193, 1.121, 3.7057, 1.1213, 3.7044, 1.4159, 1.1182, 1.4155]}
# 	>>> Figure body bounding box in: (1.1193, 1.121, 3.7044, 1.4159)
# 	>>> Figure #30 has the following spans: [{'offset': 54838, 'length': 23}]
# 	>>> Span #0: {'offset': 54838, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 17, 'polygon': [1.1067, 1.1149, 3.7118, 1.1147, 3.7123, 1.4344, 1.1073, 1.4346]}
# 	>>> Figure body bounding box in: (1.1067, 1.1149, 3.7123, 1.4344)
# 	>>> Figure #31 has the following spans: [{'offset': 54862, 'length': 53}]
# 	>>> Span #0: {'offset': 54862, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 17, 'polygon': [4.5684, 0.7102, 7.2998, 0.7102, 7.2996, 1.2698, 4.5684, 1.2696]}
# 	>>> Figure body bounding box in: (4.5684, 0.7102, 7.2996, 1.2698)
# 	>>> Figure #32 has the following spans: [{'offset': 56948, 'length': 7}]
# 	>>> Span #0: {'offset': 56948, 'length': 7}
# 	>>> Original figure content in markdown: Janssen
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 18, 'polygon': [4.5613, 0.7083, 5.8973, 0.7087, 5.8973, 1.2744, 4.5613, 1.2739]}
# 	>>> Figure body bounding box in: (4.5613, 0.7083, 5.8973, 1.2744)
# 	>>> Figure #33 has the following spans: [{'offset': 59743, 'length': 4}]
# 	>>> Span #0: {'offset': 59743, 'length': 4}
# 	>>> Original figure content in markdown: S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 19, 'polygon': [3.0716, 1.1506, 3.7064, 1.1507, 3.706, 1.4053, 3.0712, 1.4052]}
# 	>>> Figure body bounding box in: (3.0716, 1.1506, 3.706, 1.4053)
# 	>>> Figure #34 has the following spans: [{'offset': 59748, 'length': 53}]
# 	>>> Span #0: {'offset': 59748, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 19, 'polygon': [4.5648, 0.7108, 7.2998, 0.7105, 7.2998, 1.2924, 4.565, 1.2925]}
# 	>>> Figure body bounding box in: (4.5648, 0.7108, 7.2998, 1.2924)
# 	>>> Figure #35 has the following spans: [{'offset': 62854, 'length': 53}]
# 	>>> Span #0: {'offset': 62854, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 20, 'polygon': [4.5659, 0.7114, 7.2995, 0.7112, 7.2994, 1.2791, 4.566, 1.279]}
# 	>>> Figure body bounding box in: (4.5659, 0.7114, 7.2994, 1.2791)
# 	>>> Figure #36 has the following spans: [{'offset': 62908, 'length': 23}]
# 	>>> Span #0: {'offset': 62908, 'length': 23}
# 	>>> Original figure content in markdown: Tithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 20, 'polygon': [1.1167, 1.1237, 3.7096, 1.1238, 3.7094, 1.4347, 1.1167, 1.4345]}
# 	>>> Figure body bounding box in: (1.1167, 1.1237, 3.7094, 1.4347)
# 	>>> Figure #37 has the following spans: [{'offset': 66005, 'length': 53}]
# 	>>> Span #0: {'offset': 66005, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 21, 'polygon': [4.5667, 0.7099, 7.3015, 0.7097, 7.3016, 1.282, 4.5671, 1.282]}
# 	>>> Figure body bounding box in: (4.5667, 0.7099, 7.3016, 1.282)
# 	>>> Figure #38 has the following spans: [{'offset': 68255, 'length': 53}]
# 	>>> Span #0: {'offset': 68255, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 22, 'polygon': [4.5617, 0.7115, 7.3065, 0.7113, 7.3068, 1.2621, 4.5622, 1.262]}
# 	>>> Figure body bounding box in: (4.5617, 0.7115, 7.3068, 1.2621)
# 	>>> Figure #39 has the following spans: [{'offset': 68309, 'length': 23}]
# 	>>> Span #0: {'offset': 68309, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 22, 'polygon': [1.1045, 1.1263, 3.7078, 1.1263, 3.7079, 1.4161, 1.1045, 1.4161]}
# 	>>> Figure body bounding box in: (1.1045, 1.1263, 3.7079, 1.4161)
# 	>>> Figure #40 has the following spans: [{'offset': 70328, 'length': 53}]
# 	>>> Span #0: {'offset': 70328, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 23, 'polygon': [4.5634, 0.7114, 7.3058, 0.7112, 7.3059, 1.2627, 4.5636, 1.2626]}
# 	>>> Figure body bounding box in: (4.5634, 0.7114, 7.3059, 1.2627)
# 	>>> Figure #41 has the following spans: [{'offset': 70382, 'length': 23}]
# 	>>> Span #0: {'offset': 70382, 'length': 23}
# 	>>> Original figure content in markdown: Tithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 23, 'polygon': [1.1039, 1.1233, 3.7065, 1.1234, 3.7066, 1.41, 1.1038, 1.4099]}
# 	>>> Figure body bounding box in: (1.1039, 1.1233, 3.7066, 1.41)
# 	>>> Figure #42 has the following spans: [{'offset': 72360, 'length': 23}]
# 	>>> Span #0: {'offset': 72360, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 24, 'polygon': [1.1067, 1.1197, 3.7065, 1.1194, 3.7073, 1.43, 1.1075, 1.4302]}
# 	>>> Figure body bounding box in: (1.1067, 1.1197, 3.7073, 1.43)
# 	>>> Figure #43 has the following spans: [{'offset': 72384, 'length': 53}]
# 	>>> Span #0: {'offset': 72384, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 24, 'polygon': [4.5638, 0.7097, 7.3055, 0.7098, 7.3053, 1.2749, 4.5639, 1.2747]}
# 	>>> Figure body bounding box in: (4.5638, 0.7097, 7.3053, 1.2749)
# 	>>> Figure #44 has the following spans: [{'offset': 73063, 'length': 23}]
# 	>>> Span #0: {'offset': 73063, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 25, 'polygon': [1.1089, 1.118, 3.7124, 1.1176, 3.7131, 1.4309, 1.1096, 1.4313]}
# 	>>> Figure body bounding box in: (1.1089, 1.118, 3.7131, 1.4309)
# 	>>> Figure #45 has the following spans: [{'offset': 75418, 'length': 53}]
# 	>>> Span #0: {'offset': 75418, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 25, 'polygon': [4.5685, 0.7106, 7.2984, 0.7105, 7.2981, 1.2694, 4.5684, 1.2692]}
# 	>>> Figure body bounding box in: (4.5685, 0.7106, 7.2981, 1.2694)
# 	>>> Figure #46 has the following spans: [{'offset': 75472, 'length': 23}]
# 	>>> Span #0: {'offset': 75472, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 26, 'polygon': [1.1089, 1.1192, 3.7141, 1.1186, 3.7147, 1.4388, 1.1096, 1.4392]}
# 	>>> Figure body bounding box in: (1.1089, 1.1192, 3.7147, 1.4388)
# 	>>> Figure #47 has the following spans: [{'offset': 75496, 'length': 53}]
# 	>>> Span #0: {'offset': 75496, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 26, 'polygon': [4.5642, 0.708, 7.3033, 0.7081, 7.3033, 1.2621, 4.5644, 1.2618]}
# 	>>> Figure body bounding box in: (4.5642, 0.708, 7.3033, 1.2621)
# 	>>> Figure #48 has the following spans: [{'offset': 76048, 'length': 23}]
# 	>>> Span #0: {'offset': 76048, 'length': 23}
# 	>>> Original figure content in markdown: Ethnor del Istmo, S. A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 27, 'polygon': [1.1037, 1.1161, 3.7122, 1.1159, 3.7126, 1.431, 1.1042, 1.4312]}
# 	>>> Figure body bounding box in: (1.1037, 1.1161, 3.7126, 1.431)
# 	>>> Figure #49 has the following spans: [{'offset': 76072, 'length': 53}]
# 	>>> Span #0: {'offset': 76072, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 27, 'polygon': [4.5684, 0.7096, 7.3002, 0.7096, 7.2999, 1.2704, 4.5682, 1.2702]}
# 	>>> Figure body bounding box in: (4.5684, 0.7096, 7.2999, 1.2704)
# 	>>> Figure #50 has the following spans: [{'offset': 77479, 'length': 23}]
# 	>>> Span #0: {'offset': 77479, 'length': 23}
# 	>>> Original figure content in markdown: Ethnor del Istmo, S. A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 28, 'polygon': [1.1092, 1.119, 3.7305, 1.1186, 3.7315, 1.4545, 1.1103, 1.4548]}
# 	>>> Figure body bounding box in: (1.1092, 1.119, 3.7315, 1.4545)
# 	>>> Figure #51 has the following spans: [{'offset': 77503, 'length': 53}]
# 	>>> Span #0: {'offset': 77503, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 28, 'polygon': [4.5667, 0.7075, 7.301, 0.7076, 7.3007, 1.2664, 4.5666, 1.2661]}
# 	>>> Figure body bounding box in: (4.5667, 0.7075, 7.3007, 1.2664)
# 	>>> Figure #52 has the following spans: [{'offset': 79234, 'length': 23}]
# 	>>> Span #0: {'offset': 79234, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 29, 'polygon': [1.1132, 1.1173, 3.7108, 1.117, 3.7111, 1.4321, 1.1136, 1.4323]}
# 	>>> Figure body bounding box in: (1.1132, 1.1173, 3.7111, 1.4321)
# 	>>> Figure #53 has the following spans: [{'offset': 79258, 'length': 53}]
# 	>>> Span #0: {'offset': 79258, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 29, 'polygon': [4.5684, 0.7095, 7.3013, 0.7096, 7.301, 1.2684, 4.5684, 1.2681]}
# 	>>> Figure body bounding box in: (4.5684, 0.7095, 7.301, 1.2684)
# 	>>> Figure #54 has the following spans: [{'offset': 79533, 'length': 52}]
# 	>>> Span #0: {'offset': 79533, 'length': 52}
# 	>>> Original figure content in markdown: Janssen PHARMACEUTICAL COMPANIES OF Johnson &Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 29, 'polygon': [1.0126, 3.365, 2.0259, 3.3648, 2.0258, 3.8475, 1.0124, 3.8477]}
# 	>>> Figure body bounding box in: (1.0126, 3.365, 2.0258, 3.8475)
# 	>>> Figure #55 has the following spans: [{'offset': 80784, 'length': 23}]
# 	>>> Span #0: {'offset': 80784, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 30, 'polygon': [1.1142, 1.1144, 3.7094, 1.114, 3.7101, 1.4313, 1.1151, 1.4316]}
# 	>>> Figure body bounding box in: (1.1142, 1.1144, 3.7101, 1.4313)
# 	>>> Figure #56 has the following spans: [{'offset': 80899, 'length': 53}]
# 	>>> Span #0: {'offset': 80899, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 30, 'polygon': [4.567, 0.7102, 7.2966, 0.7102, 7.2966, 1.2684, 4.5671, 1.2683]}
# 	>>> Figure body bounding box in: (4.567, 0.7102, 7.2966, 1.2684)
# 	>>> Figure #57 has the following spans: [{'offset': 82169, 'length': 23}]
# 	>>> Span #0: {'offset': 82169, 'length': 23}
# 	>>> Original figure content in markdown: Eithnor del Istmo, S.A.
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 31, 'polygon': [1.1054, 1.117, 3.7137, 1.1167, 3.7143, 1.4345, 1.1061, 1.4348]}
# 	>>> Figure body bounding box in: (1.1054, 1.117, 3.7143, 1.4345)
# 	>>> Figure #58 has the following spans: [{'offset': 82193, 'length': 53}]
# 	>>> Span #0: {'offset': 82193, 'length': 53}
# 	>>> Original figure content in markdown: Janssen
# PHARMACEUTICAL COMPANIES OF Johnson & Johnson
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 31, 'polygon': [4.5653, 0.7088, 7.3008, 0.7089, 7.3004, 1.2682, 4.5651, 1.268]}
# 	>>> Figure body bounding box in: (4.5653, 0.7088, 7.3004, 1.2682)
# 	>>> Figure #59 has the following spans: [{'offset': 84802, 'length': 29}]
# 	>>> Span #0: {'offset': 84802, 'length': 29}
# 	>>> Original figure content in markdown: :selected:
# Adobe Acrobat Sign
# 	>>> No caption found for this figure
# 	>>> Figure body bounding regions: {'pageNumber': 32, 'polygon': [0.5627, 10.2865, 2.4414, 10.2863, 2.4418, 10.5681, 0.563, 10.5683]}
# 	>>> Figure body bounding box in: (0.5627, 10.2865, 2.4418, 10.5681)
# {'img_0': <PIL.Image.Image image mode=RGB size=779x92 at 0x14E42C8BA50>, 'img_1': <PIL.Image.Image image mode=RGB size=822x170 at 0x14E42C75950>, 'img_2': <PIL.Image.Image image mode=RGB size=823x171 at 0x14E42C7DA10>, 'img_3': <PIL.Image.Image image mode=RGB size=781x94 at 0x14E42C40290>, 'img_4': <PIL.Image.Image image mode=RGB size=776x91 at 0x14E42BDF0D0>, 'img_5': <PIL.Image.Image image mode=RGB size=401x170 at 0x14E42BDF690>, 'img_6': <PIL.Image.Image image mode=RGB size=187x81 at 0x14E42BDF890>, 'img_7': <PIL.Image.Image image mode=RGB size=822x174 at 0x14E42BDECD0>, 'img_8': <PIL.Image.Image image mode=RGB size=822x169 at 0x14E42C427D0>, 'img_9': <PIL.Image.Image image mode=RGB size=186x82 at 0x14E42BDE490>, 'img_10': <PIL.Image.Image image mode=RGB size=822x172 at 0x14E42BDFB90>, 'img_11': <PIL.Image.Image image mode=RGB size=822x173 at 0x14E42BDFB10>, 'img_12': <PIL.Image.Image image mode=RGB size=781x93 at 0x14E42BDF150>, 'img_13': <PIL.Image.Image image mode=RGB size=823x173 at 0x14E42BDFD10>, 'img_14': <PIL.Image.Image image mode=RGB size=821x172 at 0x14E42C76510>, 'img_15': <PIL.Image.Image image mode=RGB size=779x90 at 0x14E42BDFA10>, 'img_16': <PIL.Image.Image image mode=RGB size=779x91 at 0x14E42C7D150>, 'img_17': <PIL.Image.Image image mode=RGB size=821x171 at 0x14E42BDFE50>, 'img_18': <PIL.Image.Image image mode=RGB size=822x167 at 0x14E42BF2310>, 'img_19': <PIL.Image.Image image mode=RGB size=783x95 at 0x14E42C7E390>, 'img_20': <PIL.Image.Image image mode=RGB size=823x170 at 0x14E42BDEF50>, 'img_21': <PIL.Image.Image image mode=RGB size=778x89 at 0x14E42BDFED0>, 'img_22': <PIL.Image.Image image mode=RGB size=822x171 at 0x14E42C760D0>, 'img_23': <PIL.Image.Image image mode=RGB size=779x91 at 0x14E42BDF410>, 'img_24': <PIL.Image.Image image mode=RGB size=823x172 at 0x14E42C76410>, 'img_25': <PIL.Image.Image image mode=RGB size=781x94 at 0x14E42BDF4D0>, 'img_26': <PIL.Image.Image image mode=RGB size=188x83 at 0x14E42C7C790>, 'img_27': <PIL.Image.Image image mode=RGB size=822x173 at 0x14E42BDFC10>, 'img_28': <PIL.Image.Image image mode=RGB size=821x174 at 0x14E42BDCE50>, 'img_29': <PIL.Image.Image image mode=RGB size=777x89 at 0x14E42BDD250>, 'img_30': <PIL.Image.Image image mode=RGB size=782x97 at 0x14E42C7C550>, 'img_31': <PIL.Image.Image image mode=RGB size=820x168 at 0x14E42BDD150>, 'img_32': <PIL.Image.Image image mode=RGB size=402x171 at 0x14E42BDC890>, 'img_33': <PIL.Image.Image image mode=RGB size=191x77 at 0x14E42BDD310>, 'img_34': <PIL.Image.Image image mode=RGB size=821x175 at 0x14E376E6C10>, 'img_35': <PIL.Image.Image image mode=RGB size=821x171 at 0x14E42BDD650>, 'img_36': <PIL.Image.Image image mode=RGB size=778x94 at 0x14E42BDCF10>, 'img_37': <PIL.Image.Image image mode=RGB size=821x173 at 0x14E42C75850>, 'img_38': <PIL.Image.Image image mode=RGB size=825x166 at 0x14E42C8A110>, 'img_39': <PIL.Image.Image image mode=RGB size=782x88 at 0x14E42BF21D0>, 'img_40': <PIL.Image.Image image mode=RGB size=823x166 at 0x14E42BDCBD0>, 'img_41': <PIL.Image.Image image mode=RGB size=781x87 at 0x14E42BDC690>, 'img_42': <PIL.Image.Image image mode=RGB size=781x94 at 0x14E42BDD850>, 'img_43': <PIL.Image.Image image mode=RGB size=823x171 at 0x14E42BDCE90>, 'img_44': <PIL.Image.Image image mode=RGB size=782x95 at 0x14E42BDCA10>, 'img_45': <PIL.Image.Image image mode=RGB size=820x168 at 0x14E42BDD710>, 'img_46': <PIL.Image.Image image mode=RGB size=783x97 at 0x14E42BDD350>, 'img_47': <PIL.Image.Image image mode=RGB size=822x167 at 0x14E42C77CD0>, 'img_48': <PIL.Image.Image image mode=RGB size=783x96 at 0x14E42C60F10>, 'img_49': <PIL.Image.Image image mode=RGB size=820x170 at 0x14E42BDD210>, 'img_50': <PIL.Image.Image image mode=RGB size=788x102 at 0x14E42BDDF50>, 'img_51': <PIL.Image.Image image mode=RGB size=821x168 at 0x14E42BF2850>, 'img_52': <PIL.Image.Image image mode=RGB size=781x95 at 0x14E42BDD8D0>, 'img_53': <PIL.Image.Image image mode=RGB size=821x169 at 0x14E42BDC1D0>, 'img_54': <PIL.Image.Image image mode ...
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_0.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_1.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_2.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_3.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_4.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_5.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_6.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_7.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_8.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_9.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_10.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_11.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_12.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_13.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_14.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_15.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_16.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_17.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_18.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_19.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_20.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_21.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_22.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_23.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_24.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_25.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_26.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_27.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_28.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_29.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_30.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_31.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_32.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_33.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_34.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_35.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_36.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_37.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_38.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_39.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_40.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_41.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_42.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_43.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_44.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_45.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_46.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_47.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_48.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_49.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_50.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_51.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_52.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_53.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_54.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_55.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_56.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_57.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_58.png image saved!
# C:/Users/GReyes15/OneDrive - JNJ/Documents/Documents/DCMT/data/1817854_img_59.png image saved!
